# %% [markdown]
# # 2005.A
#
# ## 题干
#
# ### 水污染背景
#   水是人类赖以生存的资源，保护水资源就是保护我们自己，对于我国大江大河水资源的保护和治理应是重中之重。专家们呼吁：“以人为本，建设文明和谐社会，改善人与自然的环境，减少污染。”
#
#   长江是我国第一、世界第三大河流，长江水质的污染程度日趋严重，已引起了相关政府部门和专家们的高度重视。2004年10月，由全国政协与中国发展研究院联合组成“保护长江万里行”考察团，从长江上游宜宾到下游上海，对沿线21个重点城市做了实地考察，揭示了一幅长江污染的真实画面，其污染程度让人触目惊心。为此，专家们提出“若不及时拯救，长江生态10年内将濒临崩溃”（附件１），并发出了“拿什么拯救癌变长江”的呼唤（附件2）。
#
# ### 数据方面
#   附件3给出了长江沿线17个观测站（地区）近两年多主要水质指标的检测数据，以及干流上７个观测站近一年多的基本数据（站点距离、水流量和水流速）。通常认为一个观测站（地区）的水质污染主要来自于本地区的排污和上游的污水。一般说来，江河自身对污染物都有一定的自然净化能力，即污染物在水环境中通过物理降解、化学降解和生物降解等使水中污染物的浓度降低。反映江河自然净化能力的指标称为**降解系数**。事实上，长江干流的自然净化能力可以认为是**近似均匀**的，根据检测可知，主要污染物**高锰酸盐指数**和**氨氮的降解系数**通常介于0.1-0.5之间，比如可以考虑取0.2　(单位：1/天)。附件4是“1995~2004年长江流域水质报告”给出的主要统计数据。下面的附表是国标(GB3838-2002) 给出的《地表水环境质量标准》中4个主要项目标准限值，其中Ⅰ、Ⅱ、Ⅲ类为可饮用水。
#
#   请你们研究下列问题：
#
# 1. 对长江近两年多的水质情况做出定量的综合评价，并分析各地区水质的污染状况。
# 2. 研究、分析长江干流近一年多主要污染物高锰酸盐指数和氨氮的污染源主要在哪些地区?
# 3. 假如不采取更有效的治理措施，依照过去10年的主要统计数据，对长江未来水质污染的发展趋势做出预测分析，比如研究未来10年的情况。
# 4. 根据你的预测分析，如果未来10年内每年都要求长江干流的Ⅳ类和Ⅴ类水的比例控制在20%以内，且没有劣Ⅴ类水,那么每年需要处理多少污水？
# 5. 你对解决长江水质污染问题有什么切实可行的建议和意见。

# %% [markdown]
# # 第一题
# 是对近两年多的水质情况做出定量综合评价，并分析各地区水质的污染状况，首先我们先看附录的数据，理一下数据分别含有什么：
#
# ## 附录3
#
# 1. 长江流域主要城市水质检测报告，其中包含了点位名称、断面情况、主要检测项目（单位是mg/L，包括了pH/DO/CODMn等指标）、水质类别和主要污染指标
# 2. 长江干流主要观测站点的基本数据，主要给出了7个观测站点从2004年4月到2005年4月这12个月间的水流量和水流速
#
# ## 附录4
#
# 给出了从1995年到2004年长江流域水质的报告，时段上分为枯水期、丰水期和水文年，从分别从全流域、干流、支流划分成6个污染等级，统计了不同污染等级的河流的长度和所占比例
#
# 有了数据，再来看题目的两个问题：
# 1. 对两年多的水质情况做出定量综合评价
# 2. 对各地区水质的污染状况进行分析
#
# 我们先来看第一个问题，对两年多的水质情况做出定量综合评价，结合题干的*附件3给出了长江沿线17个观测站（地区）近两年多主要水质指标的检测数据*，我们首先需要获取附件3的表格

# %%
import os
for dirname, _, filenames in os.walk('.\datasets'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# 任何在这个工程文件夹的datasets子文件夹中的文件将被输出

#忽略警告
import warnings
warnings.filterwarnings('ignore')
# Out:
# .\datasets\data1.csv
# .\datasets\data1.docx
# .\datasets\data2.csv
# .\datasets\data2.docx
# .\datasets\data3.doc
# .\datasets\yanan1.png
# .\datasets\长江水污染--附件1.doc
# .\datasets\长江水污染--附件2.doc
# .\datasets\长江水污染--附件3.doc
# .\datasets\长江水污染--附件4.doc
# .\datasets\题目.doc

# %% [markdown]
# 我们需要读取data3.doc中的表格，但是这个表格是word内置的，得想办法提取出来，问问chatgpt，得到一个读取doc中表格为df格式的代码，但是得到的代码都不能用，因此先将doc文件转换为csv文件先，但是gpt给的代码基本都用不了，暂时想不明白原因，使用CSDN的这段代码：
#
# https://blog.csdn.net/qq_34464926/article/details/104182736

# %%
from docx import Document
import csv


### 这里首先要用WPS Office的“另存为”功能将doc文件转为docx文件
docFile = r'.\datasets\data1.docx'
document = Document(docFile)  # 读入文件
tables = document.tables  # 获取文件中的表格集

data = []
for table in tables:
    for i, row in enumerate(table.rows):  # 读每行
        row_content = []
        for cell in row.cells:  # 读一行中的所有单元格
            c = cell.text
            row_content.append(c.replace("\n", "").replace("\r", "").strip())
        data.append(row_content)

def data_write_csv(file_name, datas):  # file_name为写入CSV文件的路径，datas为要写入数据列表
    with open(file_name, 'w', newline='', encoding='utf-8') as file_csv:
        writer = csv.writer(file_csv)
        for data in datas:
            writer.writerow(data)
        print("保存文件成功，处理结束")

data_write_csv(r".\datasets\data1.csv", data)
# Out:
# 保存文件成功，处理结束

# %%
### 接下来要将csv文件存入df中
import pandas as pd

csv_file_path = r".\datasets\data1.csv"  # Replace with your CSV file path
dataframe = pd.read_csv(csv_file_path)

print(dataframe)
# Out:
#           序号     点位名称        断面情况 主要监测项目(单位:mg/L) 主要监测项目(单位:mg/L).1  \
# 0         序号     点位名称        断面情况             pH*                DO
# 1          1    四川攀枝花          干流             7.6               6.8
# 2          2     重庆朱沱   干流（川-渝省界）            7.63              8.41
# 3          3  湖北宜昌南津关  干流（三峡水库出口）            7.07              7.81
# 4          4  湖南岳阳城陵矶          干流            7.58              6.47
# ..       ...      ...         ...             ...               ...
# 554  2005.02      水流速         2.0             1.0               0.4
# 555  2005.03      水流量         623            4740              5180
# 556  2005.03      水流速         1.9             0.9               0.4
# 557  2005.04      水流量         642            3650              5400
# 558  2005.04      水流速         2.1             1.2               0.4
#
#     主要监测项目(单位:mg/L).2 主要监测项目(单位:mg/L).3   水质类别 水质类别.1  主要污染指标
# 0               CODMn             NH3-N     本月     上月  主要污染指标
# 1                 0.2               0.1     II      Ⅱ     NaN
# 2                 2.8              0.34     II      Ⅱ     NaN
# 3                 5.8              0.55    III      Ⅲ     NaN
# 4                 2.9              0.34     II      Ⅱ     NaN
# ..                ...               ...    ...    ...     ...
# 554               0.6               0.7    0.7    0.8     NaN
# 555              7040             14300  21400  21500     NaN
# 556               0.6               0.8    0.8    0.9     NaN
# 557              7240             15100  20200  22100     NaN
# 558               0.5               0.7    0.8    0.8     NaN
#
# [559 rows x 10 columns]

# %%
### 删除第二个表
dataframe = dataframe[:531]
dataframe[:20]
# Out:
#     序号      点位名称         断面情况  主要监测项目(单位:mg/L) 主要监测项目(单位:mg/L).1  \
# 0   序号      点位名称         断面情况              pH*                DO
# 1    1     四川攀枝花           干流              7.6               6.8
# 2    2      重庆朱沱    干流（川-渝省界）             7.63              8.41
# 3    3   湖北宜昌南津关   干流（三峡水库出口）             7.07              7.81
# 4    4   湖南岳阳城陵矶           干流             7.58              6.47
# 5    5  江西九江河西水厂    干流（鄂-赣省界）             7.34              6.19
# 6    6   安徽安庆皖河口           干流             7.52              6.54
# 7    7    江苏南京林山    干流（皖-苏省界）             7.78               6.9
# 8    8  四川乐山岷江大桥  岷江（与大渡河汇合前）             7.66               4.2
# 9    9   四川宜宾凉姜沟     岷江（入长江前）             8.01              7.63
# 10  10  四川泸州沱江二桥     沱江（入长江前）             7.63              4.02
# 11  11  湖北丹江口胡家岭    丹江口水库（库体）             8.63              10.2
# 12  12    湖南长沙新港    湘江（洞庭湖入口）             7.42              6.45
# 13  13   湖南岳阳岳阳楼        洞庭湖出口             7.73              6.26
# 14  14    湖北武汉宗关     汉江（入长江前）                8              6.43
# 15  15    江西南昌滁槎    赣江（鄱阳湖入口）             6.64              5.18
# 16  16   江西九江蛤蟆石        鄱阳湖出口             7.28              6.87
# 17  17   江苏扬州三江营  夹江（南水北调取水口）             7.29               6.9
# 18  序号      点位名称         断面情况  主要监测项目(单位:mg/L)   主要监测项目(单位:mg/L)
# 19  序号      点位名称         断面情况              pH*                DO
#
#    主要监测项目(单位:mg/L).2 主要监测项目(单位:mg/L).3  水质类别 水质类别.1  主要污染指标
# 0              CODMn             NH3-N    本月     上月  主要污染指标
# 1                0.2               0.1    II      Ⅱ     NaN
# 2                2.8              0.34    II      Ⅱ     NaN
# 3                5.8              0.55   III      Ⅲ     NaN
# 4                2.9              0.34    II      Ⅱ     NaN
# 5                1.7              0.13    II      Ⅱ     NaN
# 6                3.2              0.22    II      Ⅱ     NaN
# 7                3.1              0.11    II      Ⅱ     NaN
# 8                5.8              0.53    IV      Ⅳ     溶解氧
# 9                2.4              0.25    II      Ⅱ     NaN
# 10               3.6              1.06    IV      Ⅳ  溶解氧、氨氮
# 11               1.8               0.1     I      Ⅰ     NaN
# 12               4.3              0.99   III      Ⅲ     NaN
# 13               1.4              0.21    II      Ⅲ     NaN
# 14               2.4              0.17    II      Ⅱ     NaN
# 15               1.1              0.92   III      Ⅲ     NaN
# 16               2.7              0.15    II      Ⅱ     NaN
# 17               1.6              0.15    II      Ⅱ     NaN
# 18   主要监测项目(单位:mg/L)   主要监测项目(单位:mg/L)  水质类别   水质类别  主要污染指标
# 19             CODMn             NH3-N    本月     上月  主要污染指标

# %%
# 删除第一个数据不是数字的行
dataframe = dataframe[dataframe['序号'].apply(lambda x: str(x).isdigit())]
dataframe.drop
# Out:
# <bound method DataFrame.drop of       序号      点位名称         断面情况 主要监测项目(单位:mg/L) 主要监测项目(单位:mg/L).1  \
# 1      1     四川攀枝花           干流             7.6               6.8
# 2      2      重庆朱沱    干流（川-渝省界）            7.63              8.41
# 3      3   湖北宜昌南津关   干流（三峡水库出口）            7.07              7.81
# 4      4   湖南岳阳城陵矶           干流            7.58              6.47
# 5      5  江西九江河西水厂    干流（鄂-赣省界）            7.34              6.19
# ..   ...       ...          ...             ...               ...
# 526  472   湖南岳阳岳阳楼        洞庭湖出口            7.43              8.51
# 527  473    湖北武汉宗关     汉江（入长江前）            8.05              6.68
# 528  474    江西南昌滁槎    赣江（鄱阳湖入口）            6.39              3.39
# 529  475   江西九江蛤蟆石        鄱阳湖出口            7.64              7.39
# 530  476   江苏扬州三江营  夹江（南水北调取水口）            7.67              7.25
#
#     主要监测项目(单位:mg/L).2 主要监测项目(单位:mg/L).3 水质类别 水质类别.1 主要污染指标
# 1                 0.2               0.1   II      Ⅱ    NaN
# 2                 2.8              0.34   II      Ⅱ    NaN
# 3                 5.8              0.55  III      Ⅲ    NaN
# 4                 2.9              0.34   II      Ⅱ    NaN
# 5                 1.7              0.13   II      Ⅱ    NaN
# ..                ...               ...  ...    ...    ...
# 526               2.6              0.64    Ⅲ      Ⅱ    NaN
# 527               2.3              0.13    Ⅱ      Ⅱ    NaN
# 528               1.1              0.92    Ⅳ      Ⅳ    溶解氧
# 529               2.3              0.11    Ⅱ      Ⅱ    NaN
# 530               3.6              0.29    Ⅱ      Ⅲ    NaN
#
# [476 rows x 10 columns]>

# %% [markdown]
# 因为点位的名称在每个表格中不尽相同，但是他们的顺序是一样的，所以我们要统一这些名称，同时这里没有时间信息，因此我们需要加上时间信息，此外，序号可以删去，然后我们可以把时间作为索引

# %%
dataframe.drop(columns=['序号'], inplace=True)

# %%
dataframe
# Out:
#          点位名称         断面情况 主要监测项目(单位:mg/L) 主要监测项目(单位:mg/L).1  \
# 1       四川攀枝花           干流             7.6               6.8
# 2        重庆朱沱    干流（川-渝省界）            7.63              8.41
# 3     湖北宜昌南津关   干流（三峡水库出口）            7.07              7.81
# 4     湖南岳阳城陵矶           干流            7.58              6.47
# 5    江西九江河西水厂    干流（鄂-赣省界）            7.34              6.19
# ..        ...          ...             ...               ...
# 526   湖南岳阳岳阳楼        洞庭湖出口            7.43              8.51
# 527    湖北武汉宗关     汉江（入长江前）            8.05              6.68
# 528    江西南昌滁槎    赣江（鄱阳湖入口）            6.39              3.39
# 529   江西九江蛤蟆石        鄱阳湖出口            7.64              7.39
# 530   江苏扬州三江营  夹江（南水北调取水口）            7.67              7.25
#
#     主要监测项目(单位:mg/L).2 主要监测项目(单位:mg/L).3 水质类别 水质类别.1 主要污染指标
# 1                 0.2               0.1   II      Ⅱ    NaN
# 2                 2.8              0.34   II      Ⅱ    NaN
# 3                 5.8              0.55  III      Ⅲ    NaN
# 4                 2.9              0.34   II      Ⅱ    NaN
# 5                 1.7              0.13   II      Ⅱ    NaN
# ..                ...               ...  ...    ...    ...
# 526               2.6              0.64    Ⅲ      Ⅱ    NaN
# 527               2.3              0.13    Ⅱ      Ⅱ    NaN
# 528               1.1              0.92    Ⅳ      Ⅳ    溶解氧
# 529               2.3              0.11    Ⅱ      Ⅱ    NaN
# 530               3.6              0.29    Ⅱ      Ⅲ    NaN
#
# [476 rows x 9 columns]

# %%
location = ['四川攀枝花龙洞','重庆朱沱','湖北宜昌南津关','湖南岳阳城陵矶','江西九江河西水厂',
            '安徽安庆皖河口','江苏南京林山','四川乐山岷江大桥','四川宜宾凉姜沟','四川泸州沱江二桥',
            '湖北丹江口胡家岭','湖南长沙新港','湖南岳阳岳阳楼','湖北武汉宗关','江西南昌滁槎','江西九江蛤蟆石','江苏扬州三江营']
time = ['2003-06','2003-07','2003-08','2003-09','2003-10','2003-11','2003-12','2004-01',
        '2004-02','2004-03','2004-04','2004-05','2004-06','2004-07','2004-08','2004-09',
        '2004-10','2004-11','2004-12','2005-01','2005-02','2005-03','2005-04','2005-05','2005-06',
        '2005-07','2005-08','2005-09']

# %%
new_index = [val for val in time for i in range(17)]
new_index
# Out:
# ['2003-06',
#  '2003-06',
#  '2003-06',
#  '2003-06',
#  '2003-06',
#  '2003-06',
#  '2003-06',
#  '2003-06',
#  '2003-06',
#  '2003-06',
#  '2003-06',
#  '2003-06',
#  '2003-06',
#  '2003-06',
#  '2003-06',
#  '2003-06',
#  '2003-06',
#  '2003-07',
#  '2003-07',
#  '2003-07',
#  '2003-07',
#  '2003-07',
#  '2003-07',
#  '2003-07',
#  '2003-07',
#  '2003-07',
#  '2003-07',
#  '2003-07',
#  '2003-07',
#  '2003-07',
#  '2003-07',
#  '2003-07',
#  '2003-07',
#  '2003-07',
#  '2003-08',
#  '2003-08',
#  '2003-08',
#  '2003-08',
#  '2003-08',
#  '2003-08',
#  '2003-08',
#  '2003-08',
#  '2003-08',
#  '2003-08',
#  '2003-08',
#  '2003-08',
#  '2003-08',
#  '2003-08',
#  '2003-08',
#  '2003-08',
#  '2003-08',
#  '2003-09',
#  '2003-09',
#  '2003-09',
#  '2003-09',
#  '2003-09',
#  '2003-09',
#  '2003-09',
#  '2003-09',
#  '2003-09',
#  '2003-09',
#  '2003-09',
#  '2003-09',
#  '2003-09',
#  '2003-09',
#  '2003-09',
#  '2003-09',
#  '2003-09',
#  '2003-10',
#  '2003-10',
#  '2003-10',
#  '2003-10',
#  '2003-10',
#  '2003-10',
#  '2003-10',
#  '2003-10',
#  '2003-10',
#  '2003-10',
#  '2003-10',
#  '2003-10',
#  '2003-10',
#  '2003-10',
#  '2003-10',
#  '2003-10',
#  '2003-10',
#  '2003-11',
#  '2003-11',
#  '2003-11',
#  '2003-11',
#  '2003-11',
#  '2003-11',
#  '2003-11',
#  '2003-11',
#  '2003-11',
#  '2003-11',
#  '2003-11',
#  '2003-11',
#  '2003-11',
#  '2003-11',
#  '2003-11',
#  '2003-11',
#  '2003-11',
#  '2003-12',
#  '2003-12',
#  '2003-12',
#  '2003-12',
#  '2003-12',
#  '2003-12',
#  '2003-12',
#  '2003-12',
#  '2003-12',
#  '2003-12',
#  '2003-12',
#  '2003-12',
#  '2003-12',
#  '2003-12',
#  '2003-12',
#  '2003-12',
#  '2003-12',
#  '2004-01',
#  '2004-01',
#  '2004-01',
#  '2004-01',
#  '2004-01',
#  '2004-01',
#  '2004-01',
#  '2004-01',
#  '2004-01',
#  '2004-01',
#  '2004-01',
#  '2004-01',
#  '2004-01',
#  '2004-01',
#  '2004-01',
#  '2004-01',
#  '2004-01',
#  '2004-02',
#  '2004-02',
#  '2004-02',
#  '2004-02',
#  '2004-02',
#  '2004-02',
#  '2004-02',
#  '2004-02',
#  '2004-02',
#  '2004-02',
#  '2004-02',
#  '2004-02',
#  '2004-02',
#  '2004-02',
#  '2004-02',
#  '2004-02',
#  '2004-02',
#  '2004-03',
#  '2004-03',
#  '2004-03',
#  '2004-03',
#  '2004-03',
#  '2004-03',
#  '2004-03',
#  '2004-03',
#  '2004-03',
#  '2004-03',
#  '2004-03',
#  '2004-03',
#  '2004-03',
#  '2004-03',
#  '2004-03',
#  '2004-03',
#  '2004-03',
#  '2004-04',
#  '2004-04',
#  '2004-04',
#  '2004-04',
#  '2004-04',
#  '2004-04',
#  '2004-04',
#  '2004-04',
#  '2004-04',
#  '2004-04',
#  '2004-04',
#  '2004-04',
#  '2004-04',
#  '2004-04',
#  '2004-04',
#  '2004-04',
#  '2004-04',
#  '2004-05',
#  '2004-05',
#  '2004-05',
#  '2004-05',
#  '2004-05',
#  '2004-05',
#  '2004-05',
#  '2004-05',
#  '2004-05',
#  '2004-05',
#  '2004-05',
#  '2004-05',
#  '2004-05',
#  '2004-05',
#  '2004-05',
#  '2004-05',
#  '2004-05',
#  '2004-06',
#  '2004-06',
#  '2004-06',
#  '2004-06',
#  '2004-06',
#  '2004-06',
#  '2004-06',
#  '2004-06',
#  '2004-06',
#  '2004-06',
#  '2004-06',
#  '2004-06',
#  '2004-06',
#  '2004-06',
#  '2004-06',
#  '2004-06',
#  '2004-06',
#  '2004-07',
#  '2004-07',
#  '2004-07',
#  '2004-07',
#  '2004-07',
#  '2004-07',
#  '2004-07',
#  '2004-07',
#  '2004-07',
#  '2004-07',
#  '2004-07',
#  '2004-07',
#  '2004-07',
#  '2004-07',
#  '2004-07',
#  '2004-07',
#  '2004-07',
#  '2004-08',
#  '2004-08',
#  '2004-08',
#  '2004-08',
#  '2004-08',
#  '2004-08',
#  '2004-08',
#  '2004-08',
#  '2004-08',
#  '2004-08',
#  '2004-08',
#  '2004-08',
#  '2004-08',
#  '2004-08',
#  '2004-08',
#  '2004-08',
#  '2004-08',
#  '2004-09',
#  '2004-09',
#  '2004-09',
#  '2004-09',
#  '2004-09',
#  '2004-09',
#  '2004-09',
#  '2004-09',
#  '2004-09',
#  '2004-09',
#  '2004-09',
#  '2004-09',
#  '2004-09',
#  '2004-09',
#  '2004-09',
#  '2004-09',
#  '2004-09',
#  '2004-10',
#  '2004-10',
#  '2004-10',
#  '2004-10',
#  '2004-10',
#  '2004-10',
#  '2004-10',
#  '2004-10',
#  '2004-10',
#  '2004-10',
#  '2004-10',
#  '2004-10',
#  '2004-10',
#  '2004-10',
#  '2004-10',
#  '2004-10',
#  '2004-10',
#  '2004-11',
#  '2004-11',
#  '2004-11',
#  '2004-11',
#  '2004-11',
#  '2004-11',
#  '2004-11',
#  '2004-11',
#  '2004-11',
#  '2004-11',
#  '2004-11',
#  '2004-11',
#  '2004-11',
#  '2004-11',
#  '2004-11',
#  '2004-11',
#  '2004-11',
#  '2004-12',
#  '2004-12',
#  '2004-12',
#  '2004-12',
#  '2004-12',
#  '2004-12',
#  '2004-12',
#  '2004-12',
#  '2004-12',
#  '2004-12',
#  '2004-12',
#  '2004-12',
#  '2004-12',
#  '2004-12',
#  '2004-12',
#  '2004-12',
#  '2004-12',
#  '2005-01',
#  '2005-01',
#  '2005-01',
#  '2005-01',
#  '2005-01',
#  '2005-01',
#  '2005-01',
#  '2005-01',
#  '2005-01',
#  '2005-01',
#  '2005-01',
#  '2005-01',
#  '2005-01',
#  '2005-01',
#  '2005-01',
#  '2005-01',
#  '2005-01',
#  '2005-02',
#  '2005-02',
#  '2005-02',
#  '2005-02',
#  '2005-02',
#  '2005-02',
#  '2005-02',
#  '2005-02',
#  '2005-02',
#  '2005-02',
#  '2005-02',
#  '2005-02',
#  '2005-02',
#  '2005-02',
#  '2005-02',
#  '2005-02',
#  '2005-02',
#  '2005-03',
#  '2005-03',
#  '2005-03',
#  '2005-03',
#  '2005-03',
#  '2005-03',
#  '2005-03',
#  '2005-03',
#  '2005-03',
#  '2005-03',
#  '2005-03',
#  '2005-03',
#  '2005-03',
#  '2005-03',
#  '2005-03',
#  '2005-03',
#  '2005-03',
#  '2005-04',
#  '2005-04',
#  '2005-04',
#  '2005-04',
#  '2005-04',
#  '2005-04',
#  '2005-04',
#  '2005-04',
#  '2005-04',
#  '2005-04',
#  '2005-04',
#  '2005-04',
#  '2005-04',
#  '2005-04',
#  '2005-04',
#  '2005-04',
#  '2005-04',
#  '2005-05',
#  '2005-05',
#  '2005-05',
#  '2005-05',
#  '2005-05',
#  '2005-05',
#  '2005-05',
#  '2005-05',
#  '2005-05',
#  '2005-05',
#  '2005-05',
#  '2005-05',
#  '2005-05',
#  '2005-05',
#  '2005-05',
#  '2005-05',
#  '2005-05',
#  '2005-06',
#  '2005-06',
#  '2005-06',
#  '2005-06',
#  '2005-06',
#  '2005-06',
#  '2005-06',
#  '2005-06',
#  '2005-06',
#  '2005-06',
#  '2005-06',
#  '2005-06',
#  '2005-06',
#  '2005-06',
#  '2005-06',
#  '2005-06',
#  '2005-06',
#  '2005-07',
#  '2005-07',
#  '2005-07',
#  '2005-07',
#  '2005-07',
#  '2005-07',
#  '2005-07',
#  '2005-07',
#  '2005-07',
#  '2005-07',
#  '2005-07',
#  '2005-07',
#  '2005-07',
#  '2005-07',
#  '2005-07',
#  '2005-07',
#  '2005-07',
#  '2005-08',
#  '2005-08',
#  '2005-08',
#  '2005-08',
#  '2005-08',
#  '2005-08',
#  '2005-08',
#  '2005-08',
#  '2005-08',
#  '2005-08',
#  '2005-08',
#  '2005-08',
#  '2005-08',
#  '2005-08',
#  '2005-08',
#  '2005-08',
#  '2005-08',
#  '2005-09',
#  '2005-09',
#  '2005-09',
#  '2005-09',
#  '2005-09',
#  '2005-09',
#  '2005-09',
#  '2005-09',
#  '2005-09',
#  '2005-09',
#  '2005-09',
#  '2005-09',
#  '2005-09',
#  '2005-09',
#  '2005-09',
#  '2005-09',
#  '2005-09']

# %%
# 设置时间索引
dataframe.index=new_index
dataframe[:19]
# Out:
#              点位名称         断面情况 主要监测项目(单位:mg/L) 主要监测项目(单位:mg/L).1  \
# 2003-06     四川攀枝花           干流             7.6               6.8
# 2003-06      重庆朱沱    干流（川-渝省界）            7.63              8.41
# 2003-06   湖北宜昌南津关   干流（三峡水库出口）            7.07              7.81
# 2003-06   湖南岳阳城陵矶           干流            7.58              6.47
# 2003-06  江西九江河西水厂    干流（鄂-赣省界）            7.34              6.19
# 2003-06   安徽安庆皖河口           干流            7.52              6.54
# 2003-06    江苏南京林山    干流（皖-苏省界）            7.78               6.9
# 2003-06  四川乐山岷江大桥  岷江（与大渡河汇合前）            7.66               4.2
# 2003-06   四川宜宾凉姜沟     岷江（入长江前）            8.01              7.63
# 2003-06  四川泸州沱江二桥     沱江（入长江前）            7.63              4.02
# 2003-06  湖北丹江口胡家岭    丹江口水库（库体）            8.63              10.2
# 2003-06    湖南长沙新港    湘江（洞庭湖入口）            7.42              6.45
# 2003-06   湖南岳阳岳阳楼        洞庭湖出口            7.73              6.26
# 2003-06    湖北武汉宗关     汉江（入长江前）               8              6.43
# 2003-06    江西南昌滁槎    赣江（鄱阳湖入口）            6.64              5.18
# 2003-06   江西九江蛤蟆石        鄱阳湖出口            7.28              6.87
# 2003-06   江苏扬州三江营  夹江（南水北调取水口）            7.29               6.9
# 2003-07   四川攀枝花龙洞           干流             8.3               8.1
# 2003-07      重庆朱沱    干流（川-渝省界）            7.47              8.54
#
#         主要监测项目(单位:mg/L).2 主要监测项目(单位:mg/L).3 水质类别 水质类别.1  主要污染指标
# 2003-06               0.2               0.1   II      Ⅱ     NaN
# 2003-06               2.8              0.34   II      Ⅱ     NaN
# 2003-06               5.8              0.55  III      Ⅲ     NaN
# 2003-06               2.9              0.34   II      Ⅱ     NaN
# 2003-06               1.7              0.13   II      Ⅱ     NaN
# 2003-06               3.2              0.22   II      Ⅱ     NaN
# 2003-06               3.1              0.11   II      Ⅱ     NaN
# 2003-06               5.8              0.53   IV      Ⅳ     溶解氧
# 2003-06               2.4              0.25   II      Ⅱ     NaN
# 2003-06               3.6              1.06   IV      Ⅳ  溶解氧、氨氮
# 2003-06               1.8               0.1    I      Ⅰ     NaN
# 2003-06               4.3              0.99  III      Ⅲ     NaN
# 2003-06               1.4              0.21   II      Ⅲ     NaN
# 2003-06               2.4              0.17   II      Ⅱ     NaN
# 2003-06               1.1              0.92  III      Ⅲ     NaN
# 2003-06               2.7              0.15   II      Ⅱ     NaN
# 2003-06               1.6              0.15   II      Ⅱ     NaN
# 2003-07               5.6               0.1  III     II     NaN
# 2003-07               1.6              0.25   II     II     NaN

# %%
# 重新设置地点名称
new_location = location * len(time)
dataframe['点位名称']=new_location
dataframe[:20]
# Out:
#              点位名称         断面情况 主要监测项目(单位:mg/L) 主要监测项目(单位:mg/L).1  \
# 2003-06   四川攀枝花龙洞           干流             7.6               6.8
# 2003-06      重庆朱沱    干流（川-渝省界）            7.63              8.41
# 2003-06   湖北宜昌南津关   干流（三峡水库出口）            7.07              7.81
# 2003-06   湖南岳阳城陵矶           干流            7.58              6.47
# 2003-06  江西九江河西水厂    干流（鄂-赣省界）            7.34              6.19
# 2003-06   安徽安庆皖河口           干流            7.52              6.54
# 2003-06    江苏南京林山    干流（皖-苏省界）            7.78               6.9
# 2003-06  四川乐山岷江大桥  岷江（与大渡河汇合前）            7.66               4.2
# 2003-06   四川宜宾凉姜沟     岷江（入长江前）            8.01              7.63
# 2003-06  四川泸州沱江二桥     沱江（入长江前）            7.63              4.02
# 2003-06  湖北丹江口胡家岭    丹江口水库（库体）            8.63              10.2
# 2003-06    湖南长沙新港    湘江（洞庭湖入口）            7.42              6.45
# 2003-06   湖南岳阳岳阳楼        洞庭湖出口            7.73              6.26
# 2003-06    湖北武汉宗关     汉江（入长江前）               8              6.43
# 2003-06    江西南昌滁槎    赣江（鄱阳湖入口）            6.64              5.18
# 2003-06   江西九江蛤蟆石        鄱阳湖出口            7.28              6.87
# 2003-06   江苏扬州三江营  夹江（南水北调取水口）            7.29               6.9
# 2003-07   四川攀枝花龙洞           干流             8.3               8.1
# 2003-07      重庆朱沱    干流（川-渝省界）            7.47              8.54
# 2003-07   湖北宜昌南津关   干流（三峡水库出口）            7.73              7.89
#
#         主要监测项目(单位:mg/L).2 主要监测项目(单位:mg/L).3 水质类别 水质类别.1  主要污染指标
# 2003-06               0.2               0.1   II      Ⅱ     NaN
# 2003-06               2.8              0.34   II      Ⅱ     NaN
# 2003-06               5.8              0.55  III      Ⅲ     NaN
# 2003-06               2.9              0.34   II      Ⅱ     NaN
# 2003-06               1.7              0.13   II      Ⅱ     NaN
# 2003-06               3.2              0.22   II      Ⅱ     NaN
# 2003-06               3.1              0.11   II      Ⅱ     NaN
# 2003-06               5.8              0.53   IV      Ⅳ     溶解氧
# 2003-06               2.4              0.25   II      Ⅱ     NaN
# 2003-06               3.6              1.06   IV      Ⅳ  溶解氧、氨氮
# 2003-06               1.8               0.1    I      Ⅰ     NaN
# 2003-06               4.3              0.99  III      Ⅲ     NaN
# 2003-06               1.4              0.21   II      Ⅲ     NaN
# 2003-06               2.4              0.17   II      Ⅱ     NaN
# 2003-06               1.1              0.92  III      Ⅲ     NaN
# 2003-06               2.7              0.15   II      Ⅱ     NaN
# 2003-06               1.6              0.15   II      Ⅱ     NaN
# 2003-07               5.6               0.1  III     II     NaN
# 2003-07               1.6              0.25   II     II     NaN
# 2003-07               5.2              0.22  III    III     NaN

# %%
### 最后改一下列索引
dataframe.columns
# Out:
# Index(['点位名称', '断面情况', '主要监测项目(单位:mg/L)', '主要监测项目(单位:mg/L).1',
#        '主要监测项目(单位:mg/L).2', '主要监测项目(单位:mg/L).3', '水质类别', '水质类别.1', '主要污染指标'],
#       dtype='object')

# %%
new_columns=['点位名称','断面情况','pH','DO','CODMn','NH3-N','本月','上月','主要污染指标']
dataframe.columns = new_columns
dataframe[:17]
# Out:
#              点位名称         断面情况    pH    DO CODMn NH3-N   本月 上月  主要污染指标
# 2003-06   四川攀枝花龙洞           干流   7.6   6.8   0.2   0.1   II  Ⅱ     NaN
# 2003-06      重庆朱沱    干流（川-渝省界）  7.63  8.41   2.8  0.34   II  Ⅱ     NaN
# 2003-06   湖北宜昌南津关   干流（三峡水库出口）  7.07  7.81   5.8  0.55  III  Ⅲ     NaN
# 2003-06   湖南岳阳城陵矶           干流  7.58  6.47   2.9  0.34   II  Ⅱ     NaN
# 2003-06  江西九江河西水厂    干流（鄂-赣省界）  7.34  6.19   1.7  0.13   II  Ⅱ     NaN
# 2003-06   安徽安庆皖河口           干流  7.52  6.54   3.2  0.22   II  Ⅱ     NaN
# 2003-06    江苏南京林山    干流（皖-苏省界）  7.78   6.9   3.1  0.11   II  Ⅱ     NaN
# 2003-06  四川乐山岷江大桥  岷江（与大渡河汇合前）  7.66   4.2   5.8  0.53   IV  Ⅳ     溶解氧
# 2003-06   四川宜宾凉姜沟     岷江（入长江前）  8.01  7.63   2.4  0.25   II  Ⅱ     NaN
# 2003-06  四川泸州沱江二桥     沱江（入长江前）  7.63  4.02   3.6  1.06   IV  Ⅳ  溶解氧、氨氮
# 2003-06  湖北丹江口胡家岭    丹江口水库（库体）  8.63  10.2   1.8   0.1    I  Ⅰ     NaN
# 2003-06    湖南长沙新港    湘江（洞庭湖入口）  7.42  6.45   4.3  0.99  III  Ⅲ     NaN
# 2003-06   湖南岳阳岳阳楼        洞庭湖出口  7.73  6.26   1.4  0.21   II  Ⅲ     NaN
# 2003-06    湖北武汉宗关     汉江（入长江前）     8  6.43   2.4  0.17   II  Ⅱ     NaN
# 2003-06    江西南昌滁槎    赣江（鄱阳湖入口）  6.64  5.18   1.1  0.92  III  Ⅲ     NaN
# 2003-06   江西九江蛤蟆石        鄱阳湖出口  7.28  6.87   2.7  0.15   II  Ⅱ     NaN
# 2003-06   江苏扬州三江营  夹江（南水北调取水口）  7.29   6.9   1.6  0.15   II  Ⅱ     NaN

# %% [markdown]
# 至此，我们得到了，近两年来，每个月份的各个观测站得到的数据

# %% [markdown]
# ## 定量综合评价
# 评价题，并且要求是定量的，首先确定使用哪些量，为了综合定量地评价，应该是要用到pH、DO、CODMn、NH3-N这些量进行评价，评价的话可以使用TOPSIS，但是TOPSIS需要权重向量，这里的权重向量用熵权法不太好获取，因为熵权法是根据信息量来确定的，这里已经给出了本月的污染等级，可以考虑用相关系数作为权重，那么我们先需要确定相关系数
#
# 相关系数最常见的就是pearson相关系数和spearman相关系数，见链接：
#
# https://blog.csdn.net/weixin_67565775/article/details/126533149
#
# 使用皮尔森相关系数的条件是：
# 1. 连续数据
# 2. 正态分布
# 3. 线性关系
#
# 不能用皮尔森相关系数就用斯皮尔曼相关系数，这里主要进行正态性检验，因为连续数据显然是有的，直接用seaborn的绘图库画直方图

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 创建一个2x2的子窗口
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

# 设置Seaborn的样式
sns.set_style('darkgrid')

# 在每个子窗口中绘制distplot
sns.distplot(dataframe['pH'], ax=axes[0, 0])
sns.distplot(dataframe['DO'], ax=axes[0, 1])  
sns.distplot(dataframe['CODMn'], ax=axes[1, 0])  
sns.distplot(dataframe['NH3-N'], ax=axes[1, 1])  

# 设置每个子窗口的标题
axes[0, 0].set_title('Distribution of pH')
axes[0, 1].set_title('Distribution of DO')
axes[1, 0].set_title('Distribution of CODMn')
axes[1, 1].set_title('Distribution of NH3-N')

# 调整子窗口之间的间距
plt.tight_layout()

# 显示图形
plt.show()

# %%
from scipy.stats import kstest
import pandas as pd

# 将数据列中的字符串转换为数值类型
dataframe['pH'] = pd.to_numeric(dataframe['pH'], errors='coerce')
dataframe['DO'] = pd.to_numeric(dataframe['DO'], errors='coerce')
dataframe['CODMn'] = pd.to_numeric(dataframe['CODMn'], errors='coerce')
dataframe['NH3-N'] = pd.to_numeric(dataframe['NH3-N'], errors='coerce')

# 进行 Kolmogorov-Smirnov 检验
kstest_result = kstest(dataframe['pH'], cdf="norm")
print(kstest_result)
kstest_result = kstest(dataframe['DO'], cdf="norm")
print(kstest_result)
kstest_result = kstest(dataframe['CODMn'], cdf="norm")
print(kstest_result)
kstest_result = kstest(dataframe['NH3-N'], cdf="norm")
print(kstest_result)
# Out:
# KstestResult(statistic=0.9999999997514225, pvalue=0.0, statistic_location=6.22, statistic_sign=-1)
# KstestResult(statistic=0.9953942615258671, pvalue=0.0, statistic_location=3.35, statistic_sign=-1)
# KstestResult(statistic=0.8428566642773604, pvalue=0.0, statistic_location=1.5, statistic_sign=-1)
# KstestResult(statistic=0.5096509158444275, pvalue=3.5766421322277903e-115, statistic_location=0.04, statistic_sign=-1)

# %%
dataframe.head()
# Out:
#              点位名称        断面情况    pH    DO  CODMn  NH3-N   本月 上月 主要污染指标
# 2003-06   四川攀枝花龙洞          干流  7.60  6.80    0.2   0.10   II  Ⅱ    NaN
# 2003-06      重庆朱沱   干流（川-渝省界）  7.63  8.41    2.8   0.34   II  Ⅱ    NaN
# 2003-06   湖北宜昌南津关  干流（三峡水库出口）  7.07  7.81    5.8   0.55  III  Ⅲ    NaN
# 2003-06   湖南岳阳城陵矶          干流  7.58  6.47    2.9   0.34   II  Ⅱ    NaN
# 2003-06  江西九江河西水厂   干流（鄂-赣省界）  7.34  6.19    1.7   0.13   II  Ⅱ    NaN

# %% [markdown]
# 从图和p-value的结果可以看出，拒绝H0（正态性）的假设，因此不能使用Pearson相关系数，直接使用Spearson相关系数

# %%
### 将不同污染等级和数字对应起来
quality = {'II':2, 'III':3, 'IV':4, 'I':1, 'V':5, '劣V':6, 'Ⅱ':2, 'Ⅲ':3, 'Ⅳ':4, '劣Ⅴ':6, 'Ⅰ':1, 'Ⅴ':5}
dataframe['本月'] = dataframe['本月'].map(quality)
dataframe['上月'] = dataframe['上月'].map(quality)

# %%
dataframe.head()
# Out:
#              点位名称        断面情况    pH    DO  CODMn  NH3-N  本月  上月 主要污染指标
# 2003-06   四川攀枝花龙洞          干流  7.60  6.80    0.2   0.10   2   2    NaN
# 2003-06      重庆朱沱   干流（川-渝省界）  7.63  8.41    2.8   0.34   2   2    NaN
# 2003-06   湖北宜昌南津关  干流（三峡水库出口）  7.07  7.81    5.8   0.55   3   3    NaN
# 2003-06   湖南岳阳城陵矶          干流  7.58  6.47    2.9   0.34   2   2    NaN
# 2003-06  江西九江河西水厂   干流（鄂-赣省界）  7.34  6.19    1.7   0.13   2   2    NaN

# %%
### 后续出现了中文字体显示的问题，添加这段代码，也可以在之前就设置好
import matplotlib.font_manager

# 获取系统中可用的字体列表
font_list = matplotlib.font_manager.findSystemFonts(fontpaths=None, fontext='ttf')

# 打印字体列表
for font_path in font_list:
    print(font_path)
# Out:
# C:\Windows\Fonts\ITCBLKAD.TTF
# C:\Windows\Fonts\SansSerifCollection.ttf
# C:\Windows\Fonts\SCHLBKB.TTF
# C:\Windows\Fonts\COPRGTL.TTF
# C:\Windows\Fonts\STXINGKA.TTF
# C:\Windows\Fonts\BRUSHSCI.TTF
# C:\Windows\Fonts\SIMYOU.TTF
# C:\Windows\Fonts\CALISTBI.TTF
# C:\Windows\Fonts\msgothic.ttc
# C:\Windows\Fonts\GOUDOSB.TTF
# C:\Windows\Fonts\NIAGSOL.TTF
# C:\Windows\Fonts\CALISTB.TTF
# C:\Windows\Fonts\STCAIYUN.TTF
# C:\Windows\Fonts\BIZ-UDGothicB.ttc
# C:\Windows\Fonts\georgiai.ttf
# C:\Windows\Fonts\GILLUBCD.TTF
# C:\Program Files (x86)\Adobe\Acrobat DC\Resource\Font\AdobeDevanagari-Italic.otf
# C:\Windows\Fonts\LeelaUIb.ttf
# C:\Windows\Fonts\TCCEB.TTF
# C:\Program Files (x86)\Adobe\Acrobat DC\Resource\Font\AdobeDevanagari-Bold.otf
# C:\Windows\Fonts\ARIALN.TTF
# C:\Windows\Fonts\ROCC____.TTF
# C:\Windows\Fonts\PERB____.TTF
# C:\Windows\Fonts\timesbd.ttf
# C:\Windows\Fonts\BIZ-UDGothicR.ttc
# C:\Windows\Fonts\LTYPEB.TTF
# C:\Windows\Fonts\FREESCPT.TTF
# C:\Windows\Fonts\malgunsl.ttf
# C:\Windows\Fonts\TCBI____.TTF
# C:\Windows\Fonts\COPRGTB.TTF
# C:\Windows\Fonts\AGENCYB.TTF
# C:\Windows\Fonts\BELL.TTF
# C:\Windows\Fonts\PERI____.TTF
# C:\Windows\Fonts\simhei.ttf
# C:\ProgramData\kingsoft\office6\omath\DejaVuMathTeXGyre.ttf
# C:\Windows\Fonts\BOD_BLAR.TTF
# C:\Windows\Fonts\BOD_B.TTF
# C:\Windows\Fonts\georgiab.ttf
# C:\Windows\Fonts\LTYPEO.TTF
# C:\Windows\Fonts\PALSCRI.TTF
# C:\Windows\Fonts\LATINWD.TTF
# C:\Windows\Fonts\HARNGTON.TTF
# C:\Windows\Fonts\yumindb.ttf
# C:\Windows\Fonts\FRAHV.TTF
# C:\Windows\Fonts\UDDigiKyokashoN-R.ttc
# C:\Windows\Fonts\seguiemj.ttf
# C:\Windows\Fonts\BRLNSR.TTF
# C:\Windows\Fonts\seguibli.ttf
# C:\Windows\Fonts\LCALLIG.TTF
# C:\Windows\Fonts\CALIFI.TTF
# C:\Windows\Fonts\timesbi.ttf
# C:\Windows\Fonts\MTCORSVA.TTF
# C:\Windows\Fonts\LSANSDI.TTF
# C:\Windows\Fonts\corbelb.ttf
# C:\Windows\Fonts\BELLB.TTF
# C:\Windows\Fonts\LHANDW.TTF
# C:\Windows\Fonts\FRADM.TTF
# C:\Windows\Fonts\GOUDOS.TTF
# C:\Windows\Fonts\ENGR.TTF
# C:\Windows\Fonts\seguisym.ttf
# C:\Windows\Fonts\NirmalaS.ttf
# C:\Windows\Fonts\LFAXDI.TTF
# C:\Windows\Fonts\CENSCBK.TTF
# C:\Windows\Fonts\PERTILI.TTF
# C:\Windows\Fonts\STXINWEI.TTF
# C:\Windows\Fonts\LBRITEDI.TTF
# C:\Windows\Fonts\segoeuiz.ttf
# C:\Windows\Fonts\ERASBD.TTF
# C:\Windows\Fonts\SegoeIcons.ttf
# C:\Windows\Fonts\segoeuii.ttf
# C:\Windows\Fonts\BOD_CBI.TTF
# C:\Windows\Fonts\CURLZ___.TTF
# C:\Windows\Fonts\REFSAN.TTF
# C:\Windows\Fonts\SCRIPTBL.TTF
# C:\Windows\Fonts\verdanai.ttf
# C:\Windows\Fonts\STZHONGS.TTF
# C:\Windows\Fonts\meiryob.ttc
# C:\Windows\Fonts\FRAMDCN.TTF
# C:\Windows\Fonts\framdit.ttf
# C:\Windows\Fonts\cambriaz.ttf
# C:\Windows\Fonts\RAGE.TTF
# C:\Windows\Fonts\gadugi.ttf
# C:\Windows\Fonts\msyi.ttf
# C:\Windows\Fonts\LBRITED.TTF
# C:\Windows\Fonts\GOUDOSI.TTF
# C:\Windows\Fonts\himalaya.ttf
# C:\Windows\Fonts\SIMLI.TTF
# C:\Windows\Fonts\palabi.ttf
# C:\Windows\Fonts\timesi.ttf
# C:\Windows\Fonts\Candarai.ttf
# C:\Windows\Fonts\segoeui.ttf
# C:\Windows\Fonts\MAGNETOB.TTF
# C:\Windows\Fonts\GOTHICBI.TTF
# C:\Windows\Fonts\ariali.ttf
# C:\Windows\Fonts\constanb.ttf
# C:\Windows\Fonts\ERASLGHT.TTF
# C:\Windows\Fonts\LeelUIsl.ttf
# C:\Windows\Fonts\calibriz.ttf
# C:\Windows\Fonts\FELIXTI.TTF
# C:\Windows\Fonts\trebuc.ttf
# C:\Windows\Fonts\Candara.ttf
# C:\Windows\Fonts\ROCKI.TTF
# C:\Windows\Fonts\tahomabd.ttf
# C:\Windows\Fonts\REFSPCL.TTF
# C:\Windows\Fonts\STXIHEI.TTF
# C:\Windows\Fonts\Deng.ttf
# C:\Windows\Fonts\yumin.ttf
# C:\Windows\Fonts\SegUIVar.ttf
# C:\Windows\Fonts\NIAGENG.TTF
# C:\Windows\Fonts\LSANS.TTF
# C:\Windows\Fonts\HTOWERTI.TTF
# C:\Windows\Fonts\SitkaVF-Italic.ttf
# C:\Windows\Fonts\segoesc.ttf
# C:\Windows\Fonts\GILC____.TTF
# C:\Windows\Fonts\LeelawUI.ttf
# C:\Windows\Fonts\MATURASC.TTF
# C:\Windows\Fonts\corbell.ttf
# C:\Windows\Fonts\couri.ttf
# C:\Windows\Fonts\Inkfree.ttf
# C:\Windows\Fonts\SCHLBKI.TTF
# C:\Windows\Fonts\MISTRAL.TTF
# C:\Windows\Fonts\malgunbd.ttf
# C:\Windows\Fonts\comicz.ttf
# C:\Windows\Fonts\SCHLBKBI.TTF
# C:\Windows\Fonts\BELLI.TTF
# C:\Windows\Fonts\cambriai.ttf
# C:\Windows\Fonts\BOD_I.TTF
# C:\Windows\Fonts\constanz.ttf
# C:\Windows\Fonts\FTLTLT.TTF
# C:\Windows\Fonts\CALIST.TTF
# C:\Windows\Fonts\TEMPSITC.TTF
# C:\Windows\Fonts\BRLNSDB.TTF
# C:\Windows\Fonts\courbd.ttf
# C:\Windows\Fonts\ROCCB___.TTF
# C:\Windows\Fonts\consolab.ttf
# C:\Windows\Fonts\simkai.ttf
# C:\Windows\Fonts\CASTELAR.TTF
# C:\Windows\Fonts\WINGDNG3.TTF
# C:\Windows\Fonts\impact.ttf
# C:\Windows\Fonts\BKANT.TTF
# C:\Windows\Fonts\msmincho.ttc
# C:\Windows\Fonts\ERASMD.TTF
# C:\Windows\Fonts\MOD20.TTF
# C:\Windows\Fonts\BOD_PSTC.TTF
# C:\Windows\Fonts\mmrtextb.ttf
# C:\Windows\Fonts\comicbd.ttf
# C:\Windows\Fonts\GILI____.TTF
# C:\Windows\Fonts\BOD_CI.TTF
# C:\Windows\Fonts\LSANSI.TTF
# C:\Windows\Fonts\trebucit.ttf
# C:\Windows\Fonts\BOD_BLAI.TTF
# C:\Windows\Fonts\POORICH.TTF
# C:\Windows\Fonts\FRSCRIPT.TTF
# C:\Windows\Fonts\CALIFR.TTF
# C:\Windows\Fonts\HATTEN.TTF
# C:\Windows\Fonts\calibri.ttf
# C:\Windows\Fonts\segoeuil.ttf
# C:\Windows\Fonts\CALIFB.TTF
# C:\Windows\Fonts\wingding.ttf
# C:\Windows\Fonts\STKAITI.TTF
# C:\Windows\Fonts\GOUDYSTO.TTF
# C:\Windows\Fonts\bahnschrift.ttf
# C:\Windows\Fonts\mmrtext.ttf
# C:\Windows\Fonts\verdanab.ttf
# C:\Windows\Fonts\segoescb.ttf
# C:\Windows\Fonts\palai.ttf
# C:\Windows\Fonts\corbel.ttf
# C:\Windows\Fonts\comic.ttf
# C:\Windows\Fonts\Gabriola.ttf
# C:\Windows\Fonts\BOD_CR.TTF
# C:\Windows\Fonts\JUICE___.TTF
# C:\Windows\Fonts\cour.ttf
# C:\Windows\Fonts\YuGothL.ttc
# C:\Windows\Fonts\YuGothM.ttc
# C:\Windows\Fonts\ZWAdobeF.TTF
# C:\Windows\Fonts\CALISTI.TTF
# C:\Windows\Fonts\BRADHITC.TTF
# C:\Windows\Fonts\corbelli.ttf
# C:\Windows\Fonts\ARLRDBD.TTF
# C:\Windows\Fonts\VLADIMIR.TTF
# C:\Windows\Fonts\javatext.ttf
# C:\Windows\Fonts\BOOKOSBI.TTF
# C:\Windows\Fonts\seguihis.ttf
# C:\Windows\Fonts\GARABD.TTF
# C:\Windows\Fonts\simsunb.ttf
# C:\Windows\Fonts\PERTIBD.TTF
# C:\Windows\Fonts\LSANSD.TTF
# C:\Windows\Fonts\ITCEDSCR.TTF
# C:\Windows\Fonts\micross.ttf
# C:\Windows\Fonts\georgia.ttf
# C:\Windows\Fonts\taile.ttf
# C:\Windows\Fonts\ebrimabd.ttf
# C:\Windows\Fonts\arialbd.ttf
# C:\Windows\Fonts\Candaral.ttf
# C:\Windows\Fonts\cambria.ttc
# C:\Windows\Fonts\PERBI___.TTF
# C:\Windows\Fonts\symbol.ttf
# C:\Windows\Fonts\malgun.ttf
# C:\Windows\Fonts\DUBAI-LIGHT.TTF
# C:\Windows\Fonts\OLDENGL.TTF
# C:\Windows\Fonts\TCM_____.TTF
# C:\Windows\Fonts\BRLNSB.TTF
# C:\Windows\Fonts\yuminl.ttf
# C:\Windows\Fonts\LFAXD.TTF
# C:\Windows\Fonts\meiryo.ttc
# C:\Windows\Fonts\courbi.ttf
# C:\Windows\Fonts\consolai.ttf
# C:\Windows\Fonts\msjhbd.ttc
# C:\Windows\Fonts\times.ttf
# C:\Windows\Fonts\gadugib.ttf
# C:\Windows\Fonts\PAPYRUS.TTF
# C:\Windows\Fonts\COLONNA.TTF
# C:\Windows\Fonts\KUNSTLER.TTF
# C:\Windows\Fonts\seguili.ttf
# C:\Windows\Fonts\COOPBL.TTF
# C:\Windows\Fonts\segmdl2.ttf
# C:\Windows\Fonts\LFAX.TTF
# C:\Windows\Fonts\Dengb.ttf
# C:\Windows\Fonts\FZSTK.TTF
# C:\Windows\Fonts\GARAIT.TTF
# C:\Windows\Fonts\CENTURY.TTF
# C:\Windows\Fonts\BOD_CB.TTF
# C:\Windows\Fonts\GIL_____.TTF
# C:\Windows\Fonts\PER_____.TTF
# C:\Windows\Fonts\simfang.ttf
# C:\Windows\Fonts\FRABK.TTF
# C:\Windows\Fonts\JOKERMAN.TTF
# C:\Windows\Fonts\lucon.ttf
# C:\Windows\Fonts\ELEPHNT.TTF
# C:\Windows\Fonts\BAUHS93.TTF
# C:\Windows\Fonts\seguibl.ttf
# C:\Windows\Fonts\GLSNECB.TTF
# C:\Windows\Fonts\FZYTK.TTF
# C:\Windows\Fonts\BOOKOSB.TTF
# C:\Windows\Fonts\segoeuib.ttf
# C:\ProgramData\kingsoft\office6\mtfont\mtextra.ttf
# C:\Windows\Fonts\seguisbi.ttf
# C:\Windows\Fonts\calibrili.ttf
# C:\Windows\Fonts\ARIALNB.TTF
# C:\Windows\Fonts\msyh.ttc
# C:\Windows\Fonts\RAVIE.TTF
# C:\Windows\Fonts\GARA.TTF
# C:\Windows\Fonts\consola.ttf
# C:\Windows\Fonts\NirmalaB.ttf
# C:\Windows\Fonts\IMPRISHA.TTF
# C:\Windows\Fonts\YuGothB.ttc
# C:\Windows\Fonts\STENCIL.TTF
# C:\Windows\Fonts\STFANGSO.TTF
# C:\Windows\Fonts\trebucbd.ttf
# C:\Windows\Fonts\TCCM____.TTF
# C:\Windows\Fonts\GLECB.TTF
# C:\Windows\Fonts\AGENCYR.TTF
# C:\Windows\Fonts\ERASDEMI.TTF
# C:\Windows\Fonts\VIVALDII.TTF
# C:\Windows\Fonts\msjhl.ttc
# C:\Windows\Fonts\mingliub.ttc
# C:\Windows\Fonts\trebucbi.ttf
# C:\Windows\Fonts\corbeli.ttf
# C:\Windows\Fonts\UDDigiKyokashoN-B.ttc
# C:\Windows\Fonts\BROADW.TTF
# C:\Windows\Fonts\CHILLER.TTF
# C:\Windows\Fonts\BOOKOSI.TTF
# C:\Windows\Fonts\ALGER.TTF
# C:\Windows\Fonts\PLAYBILL.TTF
# C:\Windows\Fonts\GILBI___.TTF
# C:\Windows\Fonts\DUBAI-REGULAR.TTF
# C:\Windows\Fonts\ANTQUAI.TTF
# C:\Windows\Fonts\tahoma.ttf
# C:\Windows\Fonts\SNAP____.TTF
# C:\Windows\Fonts\segoeuisl.ttf
# C:\Windows\Fonts\ROCKEB.TTF
# C:\Windows\Fonts\FRADMIT.TTF
# C:\Windows\Fonts\framd.ttf
# C:\Windows\Fonts\OUTLOOK.TTF
# C:\Windows\Fonts\ANTQUABI.TTF
# C:\Windows\Fonts\arialbi.ttf
# C:\Windows\Fonts\l_10646.ttf
# C:\Windows\Fonts\ROCKBI.TTF
# C:\Windows\Fonts\segoepr.ttf
# C:\Windows\Fonts\OCRAEXT.TTF
# C:\Windows\Fonts\TCCB____.TTF
# C:\Windows\Fonts\BOD_R.TTF
# C:\Windows\Fonts\Candarali.ttf
# C:\Windows\Fonts\msjh.ttc
# C:\Windows\Fonts\ONYX.TTF
# C:\Windows\Fonts\ariblk.ttf
# C:\Windows\Fonts\calibrib.ttf
# C:\Windows\Fonts\mvboli.ttf
# C:\Windows\Fonts\GILSANUB.TTF
# C:\Windows\Fonts\DUBAI-MEDIUM.TTF
# C:\Windows\Fonts\PRISTINA.TTF
# C:\Windows\Fonts\FRADMCN.TTF
# C:\Windows\Fonts\Nirmala.ttf
# C:\Windows\Fonts\PARCHM.TTF
# C:\Windows\Fonts\BOD_BI.TTF
# C:\Windows\Fonts\DUBAI-BOLD.TTF
# C:\Windows\Fonts\ebrima.ttf
# C:\Windows\Fonts\georgiaz.ttf
# C:\Windows\Fonts\Dengl.ttf
# C:\Windows\Fonts\ELEPHNTI.TTF
# C:\Windows\Fonts\pala.ttf
# C:\Windows\Fonts\holomdl2.ttf
# C:\Windows\Fonts\GOTHICI.TTF
# C:\Windows\Fonts\ARIALNI.TTF
# C:\Windows\Fonts\verdana.ttf
# C:\Windows\Fonts\ANTQUAB.TTF
# C:\Windows\Fonts\STSONG.TTF
# C:\Windows\Fonts\BASKVILL.TTF
# C:\Windows\Fonts\ITCKRIST.TTF
# C:\Windows\Fonts\taileb.ttf
# C:\Windows\Fonts\consolaz.ttf
# C:\Windows\Fonts\INFROMAN.TTF
# C:\Windows\Fonts\HTOWERT.TTF
# C:\Windows\Fonts\segoeprb.ttf
# C:\Windows\Fonts\BSSYM7.TTF
# C:\Windows\Fonts\msyhl.ttc
# C:\Windows\Fonts\CENTAUR.TTF
# C:\Windows\Fonts\ntailub.ttf
# C:\Windows\Fonts\comici.ttf
# C:\Windows\Fonts\monbaiti.ttf
# C:\Windows\Fonts\STLITI.TTF
# C:\Windows\Fonts\FRAHVIT.TTF
# C:\Windows\Fonts\webdings.ttf
# C:\Windows\Fonts\phagspa.ttf
# C:\Windows\Fonts\GIGI.TTF
# C:\Windows\Fonts\FORTE.TTF
# C:\Windows\Fonts\constan.ttf
# C:\Windows\Fonts\seguisb.ttf
# C:\Windows\Fonts\calibril.ttf
# C:\Windows\Fonts\corbelz.ttf
# C:\Windows\Fonts\TCB_____.TTF
# C:\Windows\Fonts\ARIALNBI.TTF
# C:\Windows\Fonts\HARLOWSI.TTF
# C:\Windows\Fonts\LBRITE.TTF
# C:\Windows\Fonts\arial.ttf
# C:\Windows\Fonts\ntailu.ttf
# C:\Windows\Fonts\YuGothR.ttc
# C:\Windows\Fonts\verdanaz.ttf
# C:\Windows\Fonts\palab.ttf
# C:\Windows\Fonts\Candarab.ttf
# C:\Windows\Fonts\calibrii.ttf
# C:\Program Files (x86)\Adobe\Acrobat DC\Resource\Font\AdobeDevanagari-Regular.otf
# C:\Windows\Fonts\msyhbd.ttc
# C:\Windows\Fonts\sylfaen.ttf
# C:\Windows\Fonts\Candaraz.ttf
# C:\Windows\Fonts\BIZ-UDMinchoM.ttc
# C:\Windows\Fonts\TCMI____.TTF
# C:\Windows\Fonts\ROCKB.TTF
# C:\Windows\Fonts\ROCK.TTF
# C:\Windows\Fonts\GOTHIC.TTF
# C:\Windows\Fonts\seguisli.ttf
# C:\Windows\Fonts\GOTHICB.TTF
# C:\Program Files (x86)\Adobe\Acrobat DC\Resource\Font\AdobeDevanagari-BoldItalic.otf
# C:\Windows\Fonts\BRITANIC.TTF
# C:\Windows\Fonts\constani.ttf
# C:\Windows\Fonts\SHOWG.TTF
# C:\Windows\Fonts\STHUPO.TTF
# C:\Windows\Fonts\LBRITEI.TTF
# C:\Windows\Fonts\GILB____.TTF
# C:\Windows\Fonts\VINERITC.TTF
# C:\Windows\Fonts\cambriab.ttf
# C:\Windows\Fonts\phagspab.ttf
# C:\Windows\Fonts\BERNHC.TTF
# C:\Windows\Fonts\simsun.ttc
# C:\Windows\Fonts\LTYPE.TTF
# C:\Windows\Fonts\LFAXI.TTF
# C:\Windows\Fonts\MAIAN.TTF
# C:\Windows\Fonts\BOOKOS.TTF
# C:\Windows\Fonts\LTYPEBO.TTF
# C:\Windows\Fonts\WINGDNG2.TTF
# C:\Windows\Fonts\SitkaVF.ttf
# C:\Windows\Fonts\FRABKIT.TTF

# %% [markdown]
# 最常用的微软雅黑：C:\Windows\Fonts\simhei.ttf

# %%
plt.style.use('seaborn') 
sns.set(rc={'figure.figsize': (8, 6)})  # 设置画板大小
sns.set(font='SimHei')

# %%
import pandas as pd
import seaborn as sns

# Spearman 相关性分析
corr = dataframe.corr(method='spearman')
print(corr)

# 绘制相关系数热力图
sns.heatmap(corr, annot=True, cmap="YlGnBu")
# Out:
#              pH        DO     CODMn     NH3-N        本月        上月
# pH     1.000000  0.429590  0.078306 -0.241574 -0.208519 -0.235415
# DO     0.429590  1.000000 -0.093817 -0.183637 -0.391713 -0.378291
# CODMn  0.078306 -0.093817  1.000000  0.223171  0.377517  0.253661
# NH3-N -0.241574 -0.183637  0.223171  1.000000  0.715658  0.650016
# 本月    -0.208519 -0.391713  0.377517  0.715658  1.000000  0.672872
# 上月    -0.235415 -0.378291  0.253661  0.650016  0.672872  1.000000
# <Axes: >

# %%
### 获得相关系数权重向量

cor_weights = corr['本月']
cor_weights = cor_weights[:4]
cor_weights.values
# Out:
# array([-0.20851915, -0.39171267,  0.37751671,  0.71565808])

# %%
### 使用该权重向量进行TOPSIS评价
# 1.获取数据矩阵
import numpy as np
df = dataframe[['pH','DO', 'CODMn', 'NH3-N']]

# 2.标准化数据

def norm(X):
    return X/np.sqrt((X**2).sum())

norm_matrix = df.apply(norm)

# 3.加权变换
w_norm_matrix = norm_matrix*cor_weights

# 4.求解正负理想解
V_plus = w_norm_matrix.apply(max)
V_minus = w_norm_matrix.apply(min)

# 5.计算到正负理想解的距离
S_plus = np.sqrt(((w_norm_matrix - V_plus)**2).apply(sum, axis = 1))
S_minus = np.sqrt(((w_norm_matrix - V_minus)**2).apply(sum, axis = 1))

# 6.得到分数
p_score = S_minus/(S_plus + S_minus)
p_score
# Out:
# 2003-06    0.040085
# 2003-06    0.046086
# 2003-06    0.075941
# 2003-06    0.053621
# 2003-06    0.046539
#              ...
# 2005-09    0.049488
# 2005-09    0.047283
# 2005-09    0.068710
# 2005-09    0.044428
# 2005-09    0.055457
# Length: 476, dtype: float64

# %% [markdown]
# 至此，每个月每个地区的综合评价分数已经得出了，对于区域水质污染情况，我们可以绘制热力图

# %%
from collections import Counter
# Counter函数可以得到一个字典，统计不同量出现的次数
print(Counter(dataframe['点位名称']).keys())
print(len(Counter(dataframe['点位名称']).keys()))
# Out:
# dict_keys(['四川攀枝花龙洞', '重庆朱沱', '湖北宜昌南津关', '湖南岳阳城陵矶', '江西九江河西水厂', '安徽安庆皖河口', '江苏南京林山', '四川乐山岷江大桥', '四川宜宾凉姜沟', '四川泸州沱江二桥', '湖北丹江口胡家岭', '湖南长沙新港', '湖南岳阳岳阳楼', '湖北武汉宗关', '江西南昌滁槎', '江西九江蛤蟆石', '江苏扬州三江营'])
# 17

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set()

# 横轴是年月
arr = np.zeros((17, 28))  # 初始化热图大小（17个站点，28个月）
for i in range(17):
    for j in range(28):
        arr[i][j]=p_score[i+j*17]
y_ticks = location
print(y_ticks)
x_ticks = pd.date_range('2003-06', '2005-10', freq='m')  # 横轴刻度赋值
print(len(x_ticks))
x_ticks = ['%s-%02d' % (i.year, i.month) for i in x_ticks]  # 将横轴刻度值格式化为yyyy-mm形式
print(x_ticks)

plt.style.use('seaborn') 
sns.set(rc={'figure.figsize': (8, 6)})  # 设置画板大小
sns.set(font='SimHei')  

ax = sns.heatmap(arr, cmap='Reds')  # cmap=RdYlBu_r
ax.set_xticklabels(x_ticks, rotation=45, fontsize=8)
ax.set_yticklabels(y_ticks, rotation=360, fontsize=8)

plt.show()
# Out:
# ['四川攀枝花龙洞', '重庆朱沱', '湖北宜昌南津关', '湖南岳阳城陵矶', '江西九江河西水厂', '安徽安庆皖河口', '江苏南京林山', '四川乐山岷江大桥', '四川宜宾凉姜沟', '四川泸州沱江二桥', '湖北丹江口胡家岭', '湖南长沙新港', '湖南岳阳岳阳楼', '湖北武汉宗关', '江西南昌滁槎', '江西九江蛤蟆石', '江苏扬州三江营']
# 28
# ['2003-06', '2003-07', '2003-08', '2003-09', '2003-10', '2003-11', '2003-12', '2004-01', '2004-02', '2004-03', '2004-04', '2004-05', '2004-06', '2004-07', '2004-08', '2004-09', '2004-10', '2004-11', '2004-12', '2005-01', '2005-02', '2005-03', '2005-04', '2005-05', '2005-06', '2005-07', '2005-08', '2005-09']

# %% [markdown]
# 这个热图的视觉效果不太好，可以将数据进行缩放后再绘制

# %%
p_score.max()
# Out:
# 0.9884213969458315

# %%
p_score.min()
# Out:
# 0.022933556636577108

# %%
p_score = (p_score-p_score.min())/(p_score.max()-p_score.min())
p_score.head()
# Out:
# 2003-06    0.017764
# 2003-06    0.023981
# 2003-06    0.054902
# 2003-06    0.031784
# 2003-06    0.024449
# dtype: float64

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set()

p_score

# 横轴是年月
arr = np.zeros((17, 28))  # 初始化热图大小（17个站点，28个月）
for i in range(17):
    for j in range(28):
        arr[i][j]=p_score[i+j*17]
y_ticks = location
print(y_ticks)
x_ticks = pd.date_range('2003-06', '2005-10', freq='m')  # 横轴刻度赋值
print(len(x_ticks))
x_ticks = ['%s-%02d' % (i.year, i.month) for i in x_ticks]  # 将横轴刻度值格式化为yyyy-mm形式
print(x_ticks)

plt.style.use('seaborn') 
sns.set(rc={'figure.figsize': (8, 6)})  # 设置画板大小
sns.set(font='SimHei')  

ax = sns.heatmap(arr, cmap='Reds')  # cmap=RdYlBu_r
ax.set_xticklabels(x_ticks, rotation=45, fontsize=8)
ax.set_yticklabels(y_ticks, rotation=360, fontsize=8)

plt.show()
# Out:
# ['四川攀枝花龙洞', '重庆朱沱', '湖北宜昌南津关', '湖南岳阳城陵矶', '江西九江河西水厂', '安徽安庆皖河口', '江苏南京林山', '四川乐山岷江大桥', '四川宜宾凉姜沟', '四川泸州沱江二桥', '湖北丹江口胡家岭', '湖南长沙新港', '湖南岳阳岳阳楼', '湖北武汉宗关', '江西南昌滁槎', '江西九江蛤蟆石', '江苏扬州三江营']
# 28
# ['2003-06', '2003-07', '2003-08', '2003-09', '2003-10', '2003-11', '2003-12', '2004-01', '2004-02', '2004-03', '2004-04', '2004-05', '2004-06', '2004-07', '2004-08', '2004-09', '2004-10', '2004-11', '2004-12', '2005-01', '2005-02', '2005-03', '2005-04', '2005-05', '2005-06', '2005-07', '2005-08', '2005-09']

# %% [markdown]
# 呃，结果好像一样啊，虽然热图表现不行，但是我们还是比较好计算的，因为这里分数越高代表污染程度越高，所以我们直接对每一行的分数进行求和，然后进行一个排序

# %% [markdown]
# 接下来回答第一个问题的第一个小问就是综合评价长江这两年的水质情况，这个直接由图中的数据可以得出，但是可以进一步得出一个折线图

# %%
data = np.zeros((28,1))
for i in range(28):
    for j in range(17):
        data[i]+=p_score[i+j]
data

df=pd.DataFrame(data)#这时原列表中的每个元素对应一条数据
df.index=time
df['time']=time
df.columns=['data','time']
df.head()
# Out:
#              data     time
# 2003-06  0.559008  2003-06
# 2003-07  0.589380  2003-07
# 2003-08  0.579856  2003-08
# 2003-09  0.570492  2003-09
# 2003-10  0.574053  2003-10

# %% [markdown]
# https://blog.csdn.net/qq_46621219/article/details/119298611

# %%
# 按列分面折线图
sns.relplot(data=df, x='time', y='data', kind="line", dashes=False, markers=True)
plt.xticks(rotation=90)
plt.title('近28个月长江水质水质总分（求和）')
plt.vlines([17,27], 0.52, 0.66, linestyles='dashed', colors='red')
plt.show()

# %%
### 计算不同区域的污染程度
data2 = np.zeros((17,1))
for i in range(17):
    for j in range(28):
        data2[i]+=p_score[i+j*17]
data2

df2=pd.DataFrame(data2)#这时原列表中的每个元素对应一条数据
df2['location']=location
df2.columns=['data','location']
df2.head()
# Out:
#        data  location
# 0  0.567435   四川攀枝花龙洞
# 1  0.504674      重庆朱沱
# 2  0.681798   湖北宜昌南津关
# 3  0.893529   湖南岳阳城陵矶
# 4  0.628969  江西九江河西水厂

# %%
# 按列分面折线图
sns.relplot(data=df2, x='location', y='data', kind="line", dashes=False, markers=True)
plt.xticks(rotation=90)
plt.title('近28个月长江水质水质总分（求和）')
plt.vlines([16,10], 0.2, 5, linestyles='dashed', colors='red')
plt.vlines([7], 0.2, 5, linestyles='dashed', colors='black')
plt.show()

# %% [markdown]
# 结论，结果如上图，近两年水质最好的月份为2005年9月份，水质最差的月份为2004年11月份；此外，2004年全年的污染水平较高，2004年前后污染水平相比2004年都比较低
#
# 近两年平均水质最好的地区位于湖北丹江口胡家岭地区，平均水质最差的地区位于江西南昌附近地区；平均水质次差的地区为四川乐山附近地区

# %% [markdown]
# # 第二题 研究、分析污染源所在地区
# 题干：研究、分析长江干流近一年多主要污染物高锰酸盐指数和氨氮的污染源主要在哪些地区?
#
# 由于只有附件三含有高锰酸盐指数和氨氮污染源的数据，只看附件三即可，注意附件三中的CODMn表示高锰酸盐指数、NH3-N表示氨氮，题目要求的是**近一年多**，那么时间就定在2004-9到2005-9即可，但是水流速度的数据只有2004-04到2005-04的，所以取这个部分的数据
#
# 其次，题目要求的是**污染源**，给出的数据是污染的数据，怎么找出污染源，那么我们要先看原题中的污染的定义
#
# 通常认为一个观测站（地区）的水质污染主要来自于本地区的排污和上游的污水。一般说来，江河自身对污染物都有一定的自然净化能力，即污染物在水环境中通过物理降解、化学降解和生物降解等使水中污染物的浓度降低。也就是说，一个地方的污染物总量是由
#
# $$\rho_{now}=\rho_{污染源}+\rho_{上游}$$
#
# 构成的，那么我们只需要知道$\rho_{now}$和$\rho_{上游}$即可
#
# 来自上游的部分的计算公式是：
# $\mathrm{k}=-\ln (\rho{来自上游污染} / \rho{上游部分}) / \mathrm{t}$，题目中k取0.2，可以得到
#
# $$\rho{来自上游污染}=\rho{上游部分}*e^{-0.2t}$$
#
# t如何计算呢？为了简化计算，这里就用两个站点之间的距离和水流的速度求出，这里粗略地使用两个站点水流速度的平均值来当做水流的速度，假设上游站点的水流速度是$v_{上}$，下游站点的水流速度是$v_{下}$，站点间距离为$s$那么可以得到
# $$
# t = \frac{s}{\frac{v_上+v_下}{2}}
# $$
# 代入即可得到，每个站点的污染物浓度来自上游的部分，用检测到的污染物浓度作差即可得到本地污染源的浓度，根据这个浓度可以得到污染的情况，用这个方法可以得到12个月来6个站点的本地污染物浓度，然后绘制六个折线图可以看出每个月的变化情况，取平均值可以得到平均本地污染最严重的地方，思路就在这里
#
# PS：因为第一个干流站点没有上游，所以只使用后六个干流站点

# %%
mainstream = dataframe.copy()
mainstream.head()
# Out:
#              点位名称        断面情况    pH    DO  CODMn  NH3-N  本月  上月 主要污染指标
# 2003-06   四川攀枝花龙洞          干流  7.60  6.80    0.2   0.10   2   2    NaN
# 2003-06      重庆朱沱   干流（川-渝省界）  7.63  8.41    2.8   0.34   2   2    NaN
# 2003-06   湖北宜昌南津关  干流（三峡水库出口）  7.07  7.81    5.8   0.55   3   3    NaN
# 2003-06   湖南岳阳城陵矶          干流  7.58  6.47    2.9   0.34   2   2    NaN
# 2003-06  江西九江河西水厂   干流（鄂-赣省界）  7.34  6.19    1.7   0.13   2   2    NaN

# %%
mainstream=mainstream[mainstream['断面情况'].str.contains('干流')]
mainstream[:10]
#筛选出干流
# Out:
#              点位名称        断面情况    pH    DO  CODMn  NH3-N  本月  上月 主要污染指标
# 2003-06   四川攀枝花龙洞          干流  7.60  6.80    0.2   0.10   2   2    NaN
# 2003-06      重庆朱沱   干流（川-渝省界）  7.63  8.41    2.8   0.34   2   2    NaN
# 2003-06   湖北宜昌南津关  干流（三峡水库出口）  7.07  7.81    5.8   0.55   3   3    NaN
# 2003-06   湖南岳阳城陵矶          干流  7.58  6.47    2.9   0.34   2   2    NaN
# 2003-06  江西九江河西水厂   干流（鄂-赣省界）  7.34  6.19    1.7   0.13   2   2    NaN
# 2003-06   安徽安庆皖河口          干流  7.52  6.54    3.2   0.22   2   2    NaN
# 2003-06    江苏南京林山   干流（皖-苏省界）  7.78  6.90    3.1   0.11   2   2    NaN
# 2003-07   四川攀枝花龙洞          干流  8.30  8.10    5.6   0.10   3   2    NaN
# 2003-07      重庆朱沱   干流（川-渝省界）  7.47  8.54    1.6   0.25   2   2    NaN
# 2003-07   湖北宜昌南津关  干流（三峡水库出口）  7.73  7.89    5.2   0.22   3   3    NaN

# %%
mainstream=mainstream[['点位名称','CODMn','NH3-N']]
mainstream.head()
#删掉不必要的信息
# Out:
#              点位名称  CODMn  NH3-N
# 2003-06   四川攀枝花龙洞    0.2   0.10
# 2003-06      重庆朱沱    2.8   0.34
# 2003-06   湖北宜昌南津关    5.8   0.55
# 2003-06   湖南岳阳城陵矶    2.9   0.34
# 2003-06  江西九江河西水厂    1.7   0.13

# %%
mainstream[69:75]
# 2004-4的数据从70个开始，重新设置索引
mainstream=mainstream[70:]

# %%
mainstream[90:95]
#2005-4的数据到90个，重新设置索引
mainstream=mainstream[:91]

# %%
mainstream
# Out:
#              点位名称  CODMn  NH3-N
# 2004-04   四川攀枝花龙洞    2.3   0.15
# 2004-04      重庆朱沱    3.5   0.21
# 2004-04   湖北宜昌南津关    2.2   0.27
# 2004-04   湖南岳阳城陵矶    3.3   0.26
# 2004-04  江西九江河西水厂    2.9   0.27
# ...           ...    ...    ...
# 2005-04   湖北宜昌南津关    2.4   0.13
# 2005-04   湖南岳阳城陵矶    2.9   0.42
# 2005-04  江西九江河西水厂    2.0   0.14
# 2005-04   安徽安庆皖河口    2.3   0.15
# 2005-04    江苏南京林山    1.5   0.20
#
# [91 rows x 3 columns]

# %%
### 接下来要将csv文件存入df中
import pandas as pd

csv_file_path = r".\datasets\data1.csv"  # Replace with your CSV file path
dataframe2 = pd.read_csv(csv_file_path)

# %%
dataframe2=dataframe2[531:]

# %%
dataframe2.columns=['时间','观测量','p1','p2','p3','p4','p5','p6','p7','None']
dataframe2=dataframe2[['时间','观测量','p1','p2','p3','p4','p5','p6','p7']]

# %%
dataframe2.head()
# Out:
#           时间    观测量     p1     p2     p3     p4     p5     p6     p7
# 531     观测站点   观测站点  四川攀枝花   重庆朱沱   湖北宜昌   湖南岳阳   江西九江   安徽安庆   江苏南京
# 532    站点间距离  站点间距离      0    950   1728   2123   2623   2787   3251
# 533  2004.04    水流量   3690  13800  21000  25600  28100  29500  29800
# 534  2004.04    水流速    3.7    2.1    0.9    0.9    1.0    1.1    1.2
# 535  2004.05    水流量   3720  13100  19800  20500  29800  34000  34500

# %%
dist=dataframe2.values[1].tolist()
dist=dist[2:]
dist
# Out:
# ['0', '950', '1728', '2123', '2623', '2787', '3251']

# %%
#求站点之间的相对距离
rel_dist=[]
for i in range(6):
    rel_dist.append(int(dist[i+1])-int(dist[i]))
rel_dist

#单位：km
# Out:
# [950, 778, 395, 500, 164, 464]

# %%
#求不同时期站点之间水流的速度
v=dataframe2[dataframe2['观测量'].str.contains('水流速')]
v=v.reset_index()
v.drop(['index'],inplace=True,axis=1)
rel_v=v.copy()
v.head()
# Out:
#         时间  观测量   p1   p2   p3   p4   p5   p6   p7
# 0  2004.04  水流速  3.7  2.1  0.9  0.9  1.0  1.1  1.2
# 1  2004.05  水流速  3.7  1.9  0.8  0.9  1.1  1.1  1.2
# 2  2004.06  水流速  3.9  2.1  1.2  1.3  1.5  1.5  1.6
# 3  2004.07  水流速  4.1  2.3  1.4  1.5  1.5  1.6  1.7
# 4  2004.08  水流速  3.8  2.1  1.4  1.4  1.5  1.7  1.7

# %%
for i in range(6):
    rel_v['v'+str(i+1)]=(rel_v['p'+str(i+1)].astype(float)+rel_v['p'+str(i+2)].astype(float))/2

rel_v.head()
# Out:
#         时间  观测量   p1   p2   p3   p4   p5   p6   p7    v1    v2    v3    v4  \
# 0  2004.04  水流速  3.7  2.1  0.9  0.9  1.0  1.1  1.2  2.90  1.50  0.90  0.95
# 1  2004.05  水流速  3.7  1.9  0.8  0.9  1.1  1.1  1.2  2.80  1.35  0.85  1.00
# 2  2004.06  水流速  3.9  2.1  1.2  1.3  1.5  1.5  1.6  3.00  1.65  1.25  1.40
# 3  2004.07  水流速  4.1  2.3  1.4  1.5  1.5  1.6  1.7  3.20  1.85  1.45  1.50
# 4  2004.08  水流速  3.8  2.1  1.4  1.4  1.5  1.7  1.7  2.95  1.75  1.40  1.45
#
#      v5    v6
# 0  1.05  1.15
# 1  1.10  1.15
# 2  1.50  1.55
# 3  1.55  1.65
# 4  1.60  1.70

# %%
rel_v.drop(['p1','p2','p3','p4','p5','p6','p7'],axis=1,inplace=True)

# %%
rel_v.head()
# 单位：m/s
# 注：一天有86400秒
# Out:
#         时间  观测量    v1    v2    v3    v4    v5    v6
# 0  2004.04  水流速  2.90  1.50  0.90  0.95  1.05  1.15
# 1  2004.05  水流速  2.80  1.35  0.85  1.00  1.10  1.15
# 2  2004.06  水流速  3.00  1.65  1.25  1.40  1.50  1.55
# 3  2004.07  水流速  3.20  1.85  1.45  1.50  1.55  1.65
# 4  2004.08  水流速  2.95  1.75  1.40  1.45  1.60  1.70

# %%
rel_v['t1']=(rel_dist[0]*1000)/(rel_v['v1']*86400)
rel_v['t2']=(rel_dist[1]*1000)/(rel_v['v2']*86400)
rel_v['t3']=(rel_dist[2]*1000)/(rel_v['v3']*86400)
rel_v['t4']=(rel_dist[3]*1000)/(rel_v['v4']*86400)
rel_v['t5']=(rel_dist[4]*1000)/(rel_v['v5']*86400)
rel_v['t6']=(rel_dist[5]*1000)/(rel_v['v6']*86400)
rel_v
#得到了时间咯
# Out:
#          时间  观测量    v1    v2    v3    v4    v5    v6        t1         t2  \
# 0   2004.04  水流速  2.90  1.50  0.90  0.95  1.05  1.15  3.791507   6.003086
# 1   2004.05  水流速  2.80  1.35  0.85  1.00  1.10  1.15  3.926918   6.670096
# 2   2004.06  水流速  3.00  1.65  1.25  1.40  1.50  1.55  3.665123   5.457351
# 3   2004.07  水流速  3.20  1.85  1.45  1.50  1.55  1.65  3.436053   4.867367
# 4   2004.08  水流速  2.95  1.75  1.40  1.45  1.60  1.70  3.727244   5.145503
# 5   2004.09  水流速  4.95  3.25  1.80  2.00  2.75  3.40  2.221287   2.770655
# 6   2004.10  水流速  2.70  1.90  1.55  1.60  1.65  1.80  4.072359   4.739279
# 7   2004.11  水流速  2.30  1.30  0.75  0.85  0.90  0.95  4.780596   6.926638
# 8   2004.12  水流速  2.30  1.10  0.75  0.80  0.80  0.85  4.780596   8.186027
# 9   2005.01  水流速  1.80  1.00  0.55  0.65  0.70  0.75  6.108539   9.004630
# 10  2005.02  水流速  1.50  0.70  0.50  0.65  0.70  0.75  7.330247  12.863757
# 11  2005.03  水流速  1.40  0.65  0.50  0.70  0.80  0.85  7.853836  13.853276
# 12  2005.04  水流速  1.65  0.80  0.45  0.60  0.75  0.80  6.663861  11.255787
#
#            t3        t4        t5        t6
# 0    5.079733  6.091618  1.807760  4.669887
# 1    5.378540  5.787037  1.725589  4.669887
# 2    3.657407  4.133598  1.265432  3.464755
# 3    3.152937  3.858025  1.224612  3.254770
# 4    3.265542  3.991060  1.186343  3.159041
# 5    2.539866  2.893519  0.690236  1.579521
# 6    2.949522  3.616898  1.150393  2.983539
# 7    6.095679  6.808279  2.109053  5.653021
# 8    6.095679  7.233796  2.372685  6.318083
# 9    8.312290  8.903134  2.711640  7.160494
# 10   9.143519  8.903134  2.711640  7.160494
# 11   9.143519  8.267196  2.372685  6.318083
# 12  10.159465  9.645062  2.530864  6.712963

# %% [markdown]
# <img src=".\datasets\yanan1.png" alt="Cat" width="500" height="400">
# 根据这个图和数据中的顺序可以知道，数据集给出的水库出现顺序就是长江干流从上游到下游的顺序
#
# 下面我们也有了他们之间彼此到达的时间，接下来只需要将污染物浓度情况代入公式即可

# %%
rel_t=rel_v[['时间','t1','t2','t3','t4','t5','t6']]
rel_t.head()
# Out:
#         时间        t1        t2        t3        t4        t5        t6
# 0  2004.04  3.791507  6.003086  5.079733  6.091618  1.807760  4.669887
# 1  2004.05  3.926918  6.670096  5.378540  5.787037  1.725589  4.669887
# 2  2004.06  3.665123  5.457351  3.657407  4.133598  1.265432  3.464755
# 3  2004.07  3.436053  4.867367  3.152937  3.858025  1.224612  3.254770
# 4  2004.08  3.727244  5.145503  3.265542  3.991060  1.186343  3.159041

# %%
mainstream['时间']=mainstream.index
mainstream.head(7)
# Out:
#              点位名称  CODMn  NH3-N       时间
# 2004-04   四川攀枝花龙洞    2.3   0.15  2004-04
# 2004-04      重庆朱沱    3.5   0.21  2004-04
# 2004-04   湖北宜昌南津关    2.2   0.27  2004-04
# 2004-04   湖南岳阳城陵矶    3.3   0.26  2004-04
# 2004-04  江西九江河西水厂    2.9   0.27  2004-04
# 2004-04   安徽安庆皖河口    2.8   0.22  2004-04
# 2004-04    江苏南京林山    1.5   0.02  2004-04

# %%
print(new_columns)
# Out:
# ['点位名称', '断面情况', 'pH', 'DO', 'CODMn', 'NH3-N', '本月', '上月', '主要污染指标']

# %%
new_location=['四川攀枝花龙洞','重庆朱沱','湖北宜昌南津关','湖南岳阳城陵矶','江西九江河西水厂','安徽安庆皖河口','江苏南京林山']
new_time=['2004-04','2004-05','2004-06','2004-07','2004-08','2004-09',
         '2004-10','2004-11','2004-12','2005-01','2005-02','2005-03','2005-04']
new_columns=new_time.copy()
new_columns.append('地点')
df0 = pd.DataFrame(
  columns=new_columns, # 指定列属性
  index=[0,1,2,3,4,5,6]  # 指定行索引
) 

df0['地点']=new_location

for i in range(13):
    df0[new_time[i]]=mainstream[mainstream['时间']==new_time[i]]['CODMn'].values
# df0是原始数据，即对应的CODMn的污染物浓度

# %%
df1=df0.copy()
# df1代表来自上游的CODMn浓度
for i in range(13):
    new_data=[0]
    #四川的观测站没有上游，默认设置为0
    old_data=df0[new_time[i]].values
    #old_data代表旧的数据
    
    # 对应月份的各项时间数据
    times=rel_t.iloc[i].values[1:].tolist()
    
    for j in range(6):
        new_data.append(old_data[j]*np.exp((-1)*0.2*times[j]))
    df1[new_time[i]]=new_data
print(df1.shape)
df1.T
# Out:
# (7, 14)
#                0         1         2         3         4         5         6
# 2004-04      0.0  1.077461  1.053529  0.796531  0.975894  2.020124  1.100365
# 2004-05      0.0  1.960563  0.579516  1.023169   1.13148  2.195224   1.25756
# 2004-06      0.0  1.201134  1.007168  1.828543  1.531187  2.018642  0.800157
# 2004-07      0.0  1.207145  1.246636  1.703293  1.941536   2.03519  0.886632
# 2004-08      0.0  2.752223  0.714656  1.613319  1.800532  1.814193  1.010096
# 2004-09      0.0  3.911932  2.528114  2.045827  2.186436  1.655009  1.166607
# 2004-10      0.0  0.354299  0.620114  2.051207  1.697885  1.509495  1.156305
# 2004-11      0.0  1.076269  0.500484  0.561422  0.666214  1.442888  0.710244
# 2004-12      0.0  0.615011   0.25288  0.709165  0.823661  1.430998  0.480471
# 2005-01      0.0  0.353672   0.21469  0.360377  0.859516  1.395344  0.620899
# 2005-02      0.0  0.207752  0.137385  0.321243  0.539304  1.802319  0.644779
# 2005-03      0.0  0.228674   0.11898  0.337305  0.784701  1.119911  0.763101
# 2005-04      0.0   0.29012  0.210555  0.314609  0.421346  1.205596  0.600686
# 地点       四川攀枝花龙洞      重庆朱沱   湖北宜昌南津关   湖南岳阳城陵矶  江西九江河西水厂   安徽安庆皖河口    江苏南京林山

# %%
df2
# Out:
#         data  location
# 0   0.567435   四川攀枝花龙洞
# 1   0.504674      重庆朱沱
# 2   0.681798   湖北宜昌南津关
# 3   0.893529   湖南岳阳城陵矶
# 4   0.628969  江西九江河西水厂
# 5   0.706650   安徽安庆皖河口
# 6   0.601656    江苏南京林山
# 7   1.796675  四川乐山岷江大桥
# 8   0.771495   四川宜宾凉姜沟
# 9   1.397614  四川泸州沱江二桥
# 10  0.349331  湖北丹江口胡家岭
# 11  1.131834    湖南长沙新港
# 12  1.070162   湖南岳阳岳阳楼
# 13  0.860793    湖北武汉宗关
# 14  5.281815    江西南昌滁槎
# 15  0.979766   江西九江蛤蟆石
# 16  0.768478   江苏扬州三江营

# %%
# 绘制NH3-N的上游和本地污染物浓度图
new_location=['四川攀枝花龙洞','重庆朱沱','湖北宜昌南津关','湖南岳阳城陵矶','江西九江河西水厂','安徽安庆皖河口','江苏南京林山']
new_time=['2004-04','2004-05','2004-06','2004-07','2004-08','2004-09',
         '2004-10','2004-11','2004-12','2005-01','2005-02','2005-03','2005-04']
df0 = pd.DataFrame(
  columns=new_columns, # 指定列属性
  index=[0,1,2,3,4,5,6]  # 指定行索引
) 
df0['地点']=new_location
for i in range(13):
    df0[new_time[i]]=mainstream[mainstream['时间']==new_time[i]]['CODMn'].values
# df0是原始数据，即对应的NH3-N的污染物浓度

df1=df0.copy()
# df1代表来自上游的NH-3浓度
for i in range(13):
    new_data=[0]
    #四川的观测站没有上游，默认设置为0
    old_data=df0[new_time[i]].values
    #old_data代表旧的数据
    
    # 对应月份的各项时间数据
    times=rel_t.iloc[i].values[1:].tolist()
    
    for j in range(6):
        new_data.append(old_data[j]*np.exp((-1)*0.2*times[j]))
    df1[new_time[i]]=new_data

    plt.rcParams['font.sans-serif'] = ['SimHei'] # 设置字体为SimHei
plt.rcParams['axes.unicode_minus']=False # 修复负号问题

df2=df0.copy()
# df2代表来自本地的CODMn浓度
for i in range(13):
    new_data=[0]
    #四川的观测站没有上游，默认设置为0
    old_data=df0[new_time[i]].values
    #old_data代表旧的数据
    
    # 对应月份的各项时间数据
    times=rel_t.iloc[i].values[1:].tolist()
    
    for j in range(6):
        new_data.append(old_data[j+1]-(old_data[j]*np.exp((-1)*0.2*times[j])))
    df2[new_time[i]]=new_data

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 你的数据和计算过程...

# 创建一个包含两个子图的画布
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 5), sharey=True)

# 绘制来自上游的污染物浓度子图
for i in range(6):
    ax1.plot(new_time, df1.T[i+1].values[:-1], marker='o', markersize=4, label=new_location[i+1])

ax1.set_xticks(new_time)  # 设置x轴刻度为月份
ax1.set_xticklabels(new_time, rotation=45)  # 旋转x轴刻度标签
ax1.legend()
ax1.grid()
ax1.set_ylabel('来自上游的污染物浓度（CODMn）(mg/L)')
ax1.set_title('来自上游的污染物浓度（CODMn）')

# 绘制来自本地的污染物浓度子图
for i in range(6):
    ax2.plot(new_time, df2.T[i+1].values[:-1], marker='o', markersize=4, label=new_location[i+1])

ax2.set_xticks(new_time)  # 设置x轴刻度为月份
ax2.set_xticklabels(new_time, rotation=45)  # 旋转x轴刻度标签
ax2.legend()
ax2.grid()
ax2.set_ylabel('来自本地的污染物浓度（CODMn）(mg/L)')
ax2.set_title('来自本地的污染物浓度（CODMn）')

#绘制来自本地的污染物浓度月平均值的子图
df3=df2.copy()
# 按行计算平均值，并将平均值添加到新的列 "mean" 中
df3['mean'] = df3.drop('地点', axis=1).apply(lambda row: row.astype(float).mean(), axis=1)
ax3.plot(df3['地点'],df3['mean'],marker='o',markersize=4)
ax3.set_xticklabels(df3['地点'],rotation=90)  # 旋转x轴刻度标签
ax3.set_ylabel('来自本地的污染物浓度均值（CODMn）(mg/L)')
ax3.set_title('来自本地的污染物浓度均值（COD）')
ax3.vlines([3], -0.5, 4.5, linestyles='dashed', colors='red')

# 调整子图之间的间距
plt.tight_layout()

# 显示图形
plt.show()

# %%
# 绘制NH3-N的上游和本地污染物浓度图
new_location=['四川攀枝花龙洞','重庆朱沱','湖北宜昌南津关','湖南岳阳城陵矶','江西九江河西水厂','安徽安庆皖河口','江苏南京林山']
new_time=['2004-04','2004-05','2004-06','2004-07','2004-08','2004-09',
         '2004-10','2004-11','2004-12','2005-01','2005-02','2005-03','2005-04']
df0 = pd.DataFrame(
  columns=new_columns, # 指定列属性
  index=[0,1,2,3,4,5,6]  # 指定行索引
) 
df0['地点']=new_location
for i in range(13):
    df0[new_time[i]]=mainstream[mainstream['时间']==new_time[i]]['NH3-N'].values
# df0是原始数据，即对应的NH3-N的污染物浓度

df1=df0.copy()
# df1代表来自上游的NH-3浓度
for i in range(13):
    new_data=[0]
    #四川的观测站没有上游，默认设置为0
    old_data=df0[new_time[i]].values
    #old_data代表旧的数据
    
    # 对应月份的各项时间数据
    times=rel_t.iloc[i].values[1:].tolist()
    
    for j in range(6):
        new_data.append(old_data[j]*np.exp((-1)*0.2*times[j]))
    df1[new_time[i]]=new_data

    plt.rcParams['font.sans-serif'] = ['SimHei'] # 设置字体为SimHei
plt.rcParams['axes.unicode_minus']=False # 修复负号问题

df2=df0.copy()
# df2代表来自本地的CODMn浓度
for i in range(13):
    new_data=[0]
    #四川的观测站没有上游，默认设置为0
    old_data=df0[new_time[i]].values
    #old_data代表旧的数据
    
    # 对应月份的各项时间数据
    times=rel_t.iloc[i].values[1:].tolist()
    
    for j in range(6):
        new_data.append(old_data[j+1]-(old_data[j]*np.exp((-1)*0.2*times[j])))
    df2[new_time[i]]=new_data

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 你的数据和计算过程...

# 创建一个包含两个子图的画布
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 5), sharey=True)

# 绘制来自上游的污染物浓度子图
for i in range(6):
    ax1.plot(new_time, df1.T[i+1].values[:-1], marker='o', markersize=4, label=new_location[i+1])

ax1.set_xticks(new_time)  # 设置x轴刻度为月份
ax1.set_xticklabels(new_time, rotation=45)  # 旋转x轴刻度标签
ax1.legend()
ax1.grid()
ax1.set_ylabel('来自上游的污染物浓度（NH3-N）(mg/L)')
ax1.set_title('来自上游的污染物浓度（NH3-N）')

# 绘制来自本地的污染物浓度子图
for i in range(6):
    ax2.plot(new_time, df2.T[i+1].values[:-1], marker='o', markersize=4, label=new_location[i+1])

ax2.set_xticks(new_time)  # 设置x轴刻度为月份
ax2.set_xticklabels(new_time, rotation=45)  # 旋转x轴刻度标签
ax2.legend()
ax2.grid()
ax2.set_ylabel('来自本地的污染物浓度（NH3-N）(mg/L)')
ax2.set_title('来自本地的污染物浓度（NH3-N）')

#绘制来自本地的污染物浓度月平均值的子图
df3=df2.copy()
# 按行计算平均值，并将平均值添加到新的列 "mean" 中
df3['mean'] = df3.drop('地点', axis=1).apply(lambda row: row.astype(float).mean(), axis=1)
ax3.plot(df3['地点'],df3['mean'],marker='o',markersize=4)
ax3.set_xticklabels(df3['地点'],rotation=90)  # 旋转x轴刻度标签
ax3.set_ylabel('来自本地的污染物浓度均值（NH3-N）(mg/L)')
ax3.set_title('来自本地的污染物浓度均值（NH3-N）')
ax3.vlines([1,3], -0.5, 0.5, linestyles='dashed', colors='red')

# 调整子图之间的间距
plt.tight_layout()

# 显示图形
plt.show()

# %% [markdown]
# 第二题得出的结论是，污染物浓度最高的地方
#
# - CODMn：湖南岳阳城陵矶
# - NH3-N：重庆朱沱、湖南岳阳城陵矶

# %% [markdown]
# # 第三题+第四题 预测题
# **第三题**
#
# 假如不采取更有效的治理措施，依照过去10年的主要统计数据，对长江未来水质污染的发展趋势做出预测分析，比如研究未来10年的情况。
#
# **第四题**
#
# 根据你的预测分析，如果未来10年内每年都要求长江干流的Ⅳ类和Ⅴ类水的比例控制在20%以内，且没有劣Ⅴ类水,那么每年需要处理多少污水？
#
# 这里可以说是一道经典的预测题目，如果要做的比较透彻的话可以针对不同污染物浓度进行预测，同时针对水质的评分也进行预测，这里首要的目标是选择正确的预测模型
#
# 因为是**过去十年**，所以处理的数据对象主要是附件4
#
# 首先看排污量

# %%
import numpy as np
import matplotlib.pyplot as plt

dirt = [174, 179, 183, 189, 207, 234, 220.5, 256, 270, 285]
water = [9205,9513, 9171.26, 13127, 9513, 9924, 8892.8, 10210, 9980, 9405]

# 创建一个包含两个子图的画布，设置不同的尺寸比例
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(8, 6))  # 修正了子图的定义方式

ax1.plot(dirt)
ax1.set_title('排污量（亿吨）')
ax1.set_ylabel('排污量（亿吨）')

x1 = np.cumsum(dirt)  # 求累加序列
ax2.plot(x1)
ax2.set_title('排污量累加和（亿吨）')
ax2.set_ylabel('排污量累加和（亿吨）')

ax3.plot(water)
ax3.set_title('水流量（亿立方米）')
ax3.set_ylabel('水流量（亿立方米）')

x2 = np.cumsum(water)  # 求累加序列
ax4.plot(x2)
ax4.set_title('水流量累加和（亿立方米）')
ax4.set_ylabel('水流量累加和（亿立方米）')

# 调整子图之间的间距
plt.tight_layout()

# 显示图形
plt.show()

# %% [markdown]
# 累加序列很有规律，可以考虑使用GM(1,1)进行预测：
#
# https://blog.csdn.net/Westbrook_bo/article/details/130276549
#
# 灰色预测是一种对含有不确定因素的系统进行预测的方法，有助于解决样本数量少、数据信息少和信息不完整等不确 定的问题。灰色预测 ＧＭ（１，１）模型可利用随机原始的离散非负数据列，通过一次累加的方式得到新的离散数据列，建立相应的微分方程模型，用一阶线性微分方程的解来逼近时间累加后形成的新时间序列所呈现的规律。 它通过一个序列即可进行计算，是一阶线性的动态模型。
#
# 模型步骤：
#
# - 把原始数据加工成相关数列；
# - 利用生成的相关数列进行求解，得到相应的微分方程参数；
# - 利用得到的参数进行求解预测值；
# - 对预测值进行相关检验。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import math as mt
X0 = dirt.copy()
for i in range(len(X0)-1):
    l = X0[i]/X0[i+1]
    if l <= mt.exp(-2/(len(X0)+1)) or l >= mt.exp(2/(len(X0)+1)):
        break
    else:
        pass
if i == len(X0)-2 and l > mt.exp(-2/(len(X0)+1)) and l < mt.exp(2/(len(X0)+1)):
    print('级比检验通过')
else:
    print('级比检验不通过')
    
X0 = water.copy()
for i in range(len(X0)-1):
    l = X0[i]/X0[i+1]
    if l <= mt.exp(-2/(len(X0)+1)) or l >= mt.exp(2/(len(X0)+1)):
        break
    else:
        pass
if i == len(X0)-2 and l > mt.exp(-2/(len(X0)+1)) and l < mt.exp(2/(len(X0)+1)):
    print('级比检验通过')
else:
    print('级比检验不通过')
# Out:
# 级比检验通过
# 级比检验不通过

# %% [markdown]
# 水流量的级比检验没有通过，因此我们只对排污量进行GM(1,1)预测，而水流量用最小二乘预测

# %%
import numpy as np
import math as mt

X0 = dirt.copy()
# 累加数列
X1 = [X0[0]]
add = X0[0] + X0[1]
X1.append(add)
i = 2
while i < len(X0):
    add = add + X0[i]
    X1.append(add)
    i += 1
    
# 紧邻均值序列
Z = []
j = 1
while j < len(X1):
    num = (X1[j] + X1[j - 1]) / 2
    Z.append(num)
    j = j + 1

# 最小二乘法计算
Y = []
x_i = 0
while x_i < len(X0) - 1:
    x_i += 1
    Y.append(X0[x_i])
Y = np.mat(Y)
Y = Y.reshape(-1,1)
B = []
b = 0
while b < len(Z):
    B.append(-Z[b])
    b += 1
B = np.mat(B)
B = B.reshape(-1,1)
c = np.ones((len(B),1))
B = np.hstack((B,c))
print("B",B)

# 求出参数
alpha = np.linalg.inv(B.T.dot(B)).dot(B.T).dot(Y)
a = alpha[0,0]
b = alpha[1,0]
print('alpha',alpha)
print("a=",a)
print("b=",b)

# 生成预测模型
GM = []
GM.append(X0[0])
did = b/a
k = 1
while k < len(X0)+10:
    GM.append((X0[0] - did) * mt.exp(-a * k) + did)
    k += 1

# 做差得到预测序列
G = []
G.append(X0[0])
g = 1
while g < len(X0)+10:
    G.append(round(GM[g] - GM[g - 1]))
    g += 1
print("预测数列为：",G)
# Out:
# B [[-2.63500e+02  1.00000e+00]
#  [-4.44500e+02  1.00000e+00]
#  [-6.30500e+02  1.00000e+00]
#  [-8.28500e+02  1.00000e+00]
#  [-1.04900e+03  1.00000e+00]
#  [-1.27625e+03  1.00000e+00]
#  [-1.51450e+03  1.00000e+00]
#  [-1.77750e+03  1.00000e+00]
#  [-2.05500e+03  1.00000e+00]]
# alpha [[-6.23984986e-02]
#  [ 1.56616175e+02]]
# a= -0.06239849862559037
# b= 156.6161747109068
# 预测数列为： [174, 173, 184, 196, 208, 222, 236, 251, 267, 285, 303, 323, 343, 365, 389, 414, 441, 469, 499, 531]

# %%
G
# Out:
# [174,
#  173,
#  184,
#  196,
#  208,
#  222,
#  236,
#  251,
#  267,
#  285,
#  303,
#  323,
#  343,
#  365,
#  389,
#  414,
#  441,
#  469,
#  499,
#  531]

# %%
import matplotlib.pyplot  as plt
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False 

X0 = dirt.copy()
r = range(len(X0))
t = list(r)
r0 = range(len(G))
t0 = list(r0)
plt.plot(t,X0,color='r',linestyle="--",label='true')
plt.plot(t0,G,color='b',linestyle="--",label="predict")
plt.legend()
plt.show()

# %%
### GM模型检验部分

import numpy as np
import math as mt
X0
G = G[:10]
X0 = np.array(X0)
G = np.array(G)
e = X0 - G  #残差
q = e / X0  # 相对误差
w = 0
for q_i in q:
    w += q_i
w = w/len(X0)
print('精度为{}%'.format(round((1-w)*100,2)))

s0 = np.var(X0)
s1 = np.var(e)
S0 = mt.sqrt(s0)
S1 = mt.sqrt(s1)
C = S1 / S0
print('方差比为：',C)

p = 0
for s in range(len(e)):
    if (abs(e[s]-np.mean(e)) < 0.6745 * S1):
        p = p + 1
P = p / len(e)
print('小概率误差为：',P)
# Out:
# 精度为100.02%
# 方差比为： 0.1865449307962039
# 小概率误差为： 0.5

# %% [markdown]
# 至此我们得到了未来十年排污量的曲线以及对应的数据：
#
# 303, 323, 343, 365, 389, 414, 441, 469, 499, 531（单位：亿吨）
#
# 接下来我们要得到不同类的河长，这也是一个预测问题，对于附件4的水质报告表，主要有这几个问题
# 1. 提取数据
# 2. 预测哪个数据
# 3. 使用什么预测模型
#
# 对于正式比赛的时候，枯水期、丰水期和水文年的数据应该都进行预测，这里只是做练习，仅挑选水文年的全流域的数据，首先要解决的是提取数据的问题

# %%
from docx import Document
import csv


### 这里首先要用WPS Office的“另存为”功能将doc文件转为docx文件
docFile = r'.\datasets\data2.docx'
document = Document(docFile)  # 读入文件
tables = document.tables  # 获取文件中的表格集

data = []
for table in tables:
    for i, row in enumerate(table.rows):  # 读每行
        row_content = []
        for cell in row.cells:  # 读一行中的所有单元格
            c = cell.text
            row_content.append(c.replace("\n", "").replace("\r", "").strip())
        data.append(row_content)

def data_write_csv(file_name, datas):  # file_name为写入CSV文件的路径，datas为要写入数据列表
    with open(file_name, 'w', newline='', encoding='gbk') as file_csv:
        writer = csv.writer(file_csv)
        for data in datas:
            writer.writerow(data)
        print("保存文件成功，处理结束")

data_write_csv(r".\datasets\data2.csv", data)
# Out:
# 保存文件成功，处理结束

# %%
### 接下来要将csv文件存入df中
import pandas as pd

csv_file_path = r".\datasets\data2.csv"  # Replace with your CSV file path
df = pd.read_csv(csv_file_path, encoding='gbk')

# 这里data2.csv要手动处理一下，不然会报错，要手动移动一下位置，打开文件就知道了

new_columns=['时段', '评价范围', '评价河长', 'I类河长', 'I类百分比', 'Ⅱ类河长', 'Ⅱ类百分比', 'Ⅲ类河长', 'Ⅲ类百分比',
       'Ⅳ类河长', 'Ⅳ类百分比', 'Ⅴ类河长', 'Ⅴ类百分比', '劣Ⅴ类河长', '劣Ⅴ类百分比']

df.columns=new_columns
df=df[df['评价范围']=='全流域']
print(len(df))
df=df[df['时段']=='水文年']
df=df[['I类百分比','Ⅱ类百分比','Ⅲ类百分比','Ⅳ类百分比','Ⅴ类百分比','劣Ⅴ类百分比']]
df
# Out:
# 30
#     I类百分比 Ⅱ类百分比 Ⅲ类百分比 Ⅳ类百分比 Ⅴ类百分比 劣Ⅴ类百分比
# 18   15.3  20.2  49.8   9.7   1.9    3.1
# 29   12.2  24.9  43.6  13.3   2.6    3.4
# 40   11.5  24.1  52.8   8.3   1.7    1.6
# 53    5.2  39.8  35.2   9.5   6.2    4.1
# 54    5.2  39.8  35.2   9.5   6.2    4.1
# 65    5.6  32.8  35.6  16.6   4.4    5.3
# 76    5.9  33.1  34.7    14   5.5    6.8
# 87    4.4    44  28.3    10   3.2     10
# 98    4.7  41.5  31.3   6.4   5.8   10.3
# 109   1.2  26.9  39.9  14.8   5.9   11.3

# %% [markdown]
# 根据我的思路，对每类河长做时间序列预测其实不太现实，因为这里数据集实在是太小
#
# 因此考虑使用GM(1,1)或回归模型
#
# 首先看能不能用GM(1,1)

# %%
import math as mt
columns = ['I类百分比','Ⅱ类百分比','Ⅲ类百分比','Ⅳ类百分比','Ⅴ类百分比','劣Ⅴ类百分比']
for i in columns:  
    X0 = df[i].values.astype(float).tolist()
    for i in range(len(X0)-1):
        l = X0[i]/X0[i+1]
        if l <= mt.exp(-2/(len(X0)+1)) or l >= mt.exp(2/(len(X0)+1)):
            break
        else:
            pass
    print(X0)
    if i == len(X0)-2 and l > mt.exp(-2/(len(X0)+1)) and l < mt.exp(2/(len(X0)+1)):
        print('级比检验通过')
    else:
        print('级比检验不通过')
# Out:
# [15.3, 12.2, 11.5, 5.2, 5.2, 5.6, 5.9, 4.4, 4.7, 1.2]
# 级比检验不通过
# [20.2, 24.9, 24.1, 39.8, 39.8, 32.8, 33.1, 44.0, 41.5, 26.9]
# 级比检验不通过
# [49.8, 43.6, 52.8, 35.2, 35.2, 35.6, 34.7, 28.3, 31.3, 39.9]
# 级比检验不通过
# [9.7, 13.3, 8.3, 9.5, 9.5, 16.6, 14.0, 10.0, 6.4, 14.8]
# 级比检验不通过
# [1.9, 2.6, 1.7, 6.2, 6.2, 4.4, 5.5, 3.2, 5.8, 5.9]
# 级比检验不通过
# [3.1, 3.4, 1.6, 4.1, 4.1, 5.3, 6.8, 10.0, 10.3, 11.3]
# 级比检验不通过

# %% [markdown]
# 因为不能用GM，时间序列的模型也不好用，因此直接采用回归，直接回归有点太捞了，应该结合一下排污量，但是单纯的排污量不一定能代表污染程度，还要对水流量进行预测，之前我们已经确定了水流量不能用灰色预测，因此直接对水流量进行线性（最小二乘预测）

# %%
len(water)
# Out:
# 10

# %%
import mglearn
from sklearn.linear_model import LinearRegression
x=[[i] for i in range(10)]
y=[]
for i in water:
    y.append([i])
lr=LinearRegression().fit(x, y)

# %%
print('lr.coef: {}'.format(lr.coef_))
print('lr.intercept_: {}'.format(lr.intercept_))
# Out:
# lr.coef: [[-12.29636364]]
# lr.intercept_: [9949.43963636]

# %%
new_water=[]
for i in range(10,20):
    new_water.append(float(lr.intercept_+lr.coef_*i))
trash_per=[]
for i,j in zip(G, water+new_water):
    trash_per.append(i/j)

# %%
G
# Out:
# [174,
#  173,
#  184,
#  196,
#  208,
#  222,
#  236,
#  251,
#  267,
#  285,
#  303,
#  323,
#  343,
#  365,
#  389,
#  414,
#  441,
#  469,
#  499,
#  531]

# %%
trash_per
# 污染率，用污染物的量除以水流量得到污染率，用这个+水流量作为特征对各个河流污染情况占比进行预测，这里为了后续标准化一起加了进来
# Out:
# [0.018902770233568712,
#  0.018185640702196994,
#  0.02006267404914919,
#  0.01493105812447627,
#  0.021864816566803322,
#  0.022370012091898428,
#  0.026538323137819363,
#  0.024583741429970617,
#  0.026753507014028056,
#  0.030303030303030304,
#  0.03083506233567354,
#  0.03291156387674175,
#  0.034993275318260735,
#  0.03728451500451463,
#  0.03978607347214876,
#  0.042396338624639686,
#  0.04521825737057594,
#  0.04814996611675964,
#  0.051294676130330376,
#  0.05465319613687518]

# %%
df1=df.copy()
for _ in range(10):
    df1 = df1.append({}, ignore_index=True)
    
print(df1)
df1['水流量']=water+new_water
df1['污染比']=trash_per
df1
# Out:
#    I类百分比 Ⅱ类百分比 Ⅲ类百分比 Ⅳ类百分比 Ⅴ类百分比 劣Ⅴ类百分比
# 0   15.3  20.2  49.8   9.7   1.9    3.1
# 1   12.2  24.9  43.6  13.3   2.6    3.4
# 2   11.5  24.1  52.8   8.3   1.7    1.6
# 3    5.2  39.8  35.2   9.5   6.2    4.1
# 4    5.2  39.8  35.2   9.5   6.2    4.1
# 5    5.6  32.8  35.6  16.6   4.4    5.3
# 6    5.9  33.1  34.7    14   5.5    6.8
# 7    4.4    44  28.3    10   3.2     10
# 8    4.7  41.5  31.3   6.4   5.8   10.3
# 9    1.2  26.9  39.9  14.8   5.9   11.3
# 10   NaN   NaN   NaN   NaN   NaN    NaN
# 11   NaN   NaN   NaN   NaN   NaN    NaN
# 12   NaN   NaN   NaN   NaN   NaN    NaN
# 13   NaN   NaN   NaN   NaN   NaN    NaN
# 14   NaN   NaN   NaN   NaN   NaN    NaN
# 15   NaN   NaN   NaN   NaN   NaN    NaN
# 16   NaN   NaN   NaN   NaN   NaN    NaN
# 17   NaN   NaN   NaN   NaN   NaN    NaN
# 18   NaN   NaN   NaN   NaN   NaN    NaN
# 19   NaN   NaN   NaN   NaN   NaN    NaN
#    I类百分比 Ⅱ类百分比 Ⅲ类百分比 Ⅳ类百分比 Ⅴ类百分比 劣Ⅴ类百分比           水流量       污染比
# 0   15.3  20.2  49.8   9.7   1.9    3.1   9205.000000  0.018903
# 1   12.2  24.9  43.6  13.3   2.6    3.4   9513.000000  0.018186
# 2   11.5  24.1  52.8   8.3   1.7    1.6   9171.260000  0.020063
# 3    5.2  39.8  35.2   9.5   6.2    4.1  13127.000000  0.014931
# 4    5.2  39.8  35.2   9.5   6.2    4.1   9513.000000  0.021865
# 5    5.6  32.8  35.6  16.6   4.4    5.3   9924.000000  0.022370
# 6    5.9  33.1  34.7    14   5.5    6.8   8892.800000  0.026538
# 7    4.4    44  28.3    10   3.2     10  10210.000000  0.024584
# 8    4.7  41.5  31.3   6.4   5.8   10.3   9980.000000  0.026754
# 9    1.2  26.9  39.9  14.8   5.9   11.3   9405.000000  0.030303
# 10   NaN   NaN   NaN   NaN   NaN    NaN   9826.476000  0.030835
# 11   NaN   NaN   NaN   NaN   NaN    NaN   9814.179636  0.032912
# 12   NaN   NaN   NaN   NaN   NaN    NaN   9801.883273  0.034993
# 13   NaN   NaN   NaN   NaN   NaN    NaN   9789.586909  0.037285
# 14   NaN   NaN   NaN   NaN   NaN    NaN   9777.290545  0.039786
# 15   NaN   NaN   NaN   NaN   NaN    NaN   9764.994182  0.042396
# 16   NaN   NaN   NaN   NaN   NaN    NaN   9752.697818  0.045218
# 17   NaN   NaN   NaN   NaN   NaN    NaN   9740.401455  0.048150
# 18   NaN   NaN   NaN   NaN   NaN    NaN   9728.105091  0.051295
# 19   NaN   NaN   NaN   NaN   NaN    NaN   9715.808727  0.054653

# %% [markdown]
# 接下来用岭回归来进行回归预测，特征选取水流量和污染比，分别对6类河长占比进行预测

# %%
from sklearn.linear_model import Ridge
df_X=df1[['水流量','污染比']]
df_X
# Out:
#              水流量       污染比
# 0    9205.000000  0.018903
# 1    9513.000000  0.018186
# 2    9171.260000  0.020063
# 3   13127.000000  0.014931
# 4    9513.000000  0.021865
# 5    9924.000000  0.022370
# 6    8892.800000  0.026538
# 7   10210.000000  0.024584
# 8    9980.000000  0.026754
# 9    9405.000000  0.030303
# 10   9826.476000  0.030835
# 11   9814.179636  0.032912
# 12   9801.883273  0.034993
# 13   9789.586909  0.037285
# 14   9777.290545  0.039786
# 15   9764.994182  0.042396
# 16   9752.697818  0.045218
# 17   9740.401455  0.048150
# 18   9728.105091  0.051295
# 19   9715.808727  0.054653

# %%
### 0-1标准化 MinMaxScaler
from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()
X_MinMax = min_max_scaler.fit_transform(df_X)
X_MinMax
# Out:
# array([[0.07373294, 0.09998737],
#        [0.14647395, 0.08193372],
#        [0.06576449, 0.12918781],
#        [1.        , 0.        ],
#        [0.14647395, 0.17455653],
#        [0.24354069, 0.18727476],
#        [0.        , 0.29221149],
#        [0.31108592, 0.24300513],
#        [0.25676633, 0.29762871],
#        [0.12096736, 0.38698753],
#        [0.22050824, 0.40038137],
#        [0.21760418, 0.45265705],
#        [0.21470013, 0.50506388],
#        [0.21179607, 0.56274556],
#        [0.20889201, 0.62572199],
#        [0.20598795, 0.6914351 ],
#        [0.20308389, 0.76247656],
#        [0.20017983, 0.83628197],
#        [0.19727578, 0.91544967],
#        [0.19437172, 1.        ]])

# %%
df_y=df[['I类百分比','Ⅱ类百分比','Ⅲ类百分比','Ⅳ类百分比','Ⅴ类百分比','劣Ⅴ类百分比']]
df_y.head()
# Out:
#    I类百分比 Ⅱ类百分比 Ⅲ类百分比 Ⅳ类百分比 Ⅴ类百分比 劣Ⅴ类百分比
# 18  15.3  20.2  49.8   9.7   1.9    3.1
# 29  12.2  24.9  43.6  13.3   2.6    3.4
# 40  11.5  24.1  52.8   8.3   1.7    1.6
# 53   5.2  39.8  35.2   9.5   6.2    4.1
# 54   5.2  39.8  35.2   9.5   6.2    4.1

# %%
ridge = Ridge(alpha=10).fit(df_X[:10], df_y[:10])
ridge.intercept_
ridge.coef_
# Out:
# array([[-1.00923014e-03, -1.38562973e-02],
#        [ 3.42382713e-03,  1.44875451e-02],
#        [-2.31375815e-03, -1.84549072e-02],
#        [-5.89239884e-04,  1.82957627e-03],
#        [ 5.65332682e-04,  4.23790797e-03],
#        [-7.86599123e-05,  1.17280952e-02]])

# %%
ridge.intercept_
# Out:
# array([17.10574105, -1.16603383, 61.53298265, 17.0399608 , -1.25355662,
#         6.77800622])

# %%
columns = ['I类百分比', 'Ⅱ类百分比', 'Ⅲ类百分比', 'Ⅳ类百分比', 'Ⅴ类百分比', '劣Ⅴ类百分比']
for y in range(len(columns)):
    for x in range(10, 20):
        coef_y = ridge.coef_[y]
        x_minmax_x = X_MinMax[x]
        intercept = ridge.intercept_
        
        # 计算预测值并设置到DataFrame中
        prediction = coef_y[0] * x_minmax_x[0] + coef_y[1] * x_minmax_x[1] + intercept[y]
        df1.iloc[x, y] = prediction

df1
# Out:
#         I类百分比     Ⅱ类百分比      Ⅲ类百分比      Ⅳ类百分比     Ⅴ类百分比    劣Ⅴ类百分比  \
# 0        15.3      20.2       49.8        9.7       1.9       3.1
# 1        12.2      24.9       43.6       13.3       2.6       3.4
# 2        11.5      24.1       52.8        8.3       1.7       1.6
# 3         5.2      39.8       35.2        9.5       6.2       4.1
# 4         5.2      39.8       35.2        9.5       6.2       4.1
# 5         5.6      32.8       35.6       16.6       4.4       5.3
# 6         5.9      33.1       34.7         14       5.5       6.8
# 7         4.4        44       28.3         10       3.2        10
# 8         4.7      41.5       31.3        6.4       5.8      10.3
# 9         1.2      26.9       39.9       14.8       5.9      11.3
# 10  17.099971 -1.159478  61.525083  17.040563 -1.251735  6.782685
# 11  17.099249 -1.158731  61.524125  17.040661 -1.251515  6.783298
# 12  17.098526 -1.157982  61.523165  17.040758 -1.251295  6.783913
# 13   17.09773 -1.157156  61.522107  17.040866 -1.251052  6.784589
# 14   17.09686 -1.156253  61.520952  17.040983 -1.250787  6.785328
# 15  17.095952 -1.155311  61.519746  17.041104  -1.25051  6.786099
# 16  17.094971 -1.154292  61.518441  17.041236 -1.250211  6.786933
# 17  17.093951 -1.153233  61.517086  17.041373 -1.249899  6.787798
# 18  17.092857 -1.152096  61.515632  17.041519 -1.249565  6.788727
# 19  17.091689 -1.150881  61.514078  17.041676 -1.249209  6.789719
#
#              水流量       污染比
# 0    9205.000000  0.018903
# 1    9513.000000  0.018186
# 2    9171.260000  0.020063
# 3   13127.000000  0.014931
# 4    9513.000000  0.021865
# 5    9924.000000  0.022370
# 6    8892.800000  0.026538
# 7   10210.000000  0.024584
# 8    9980.000000  0.026754
# 9    9405.000000  0.030303
# 10   9826.476000  0.030835
# 11   9814.179636  0.032912
# 12   9801.883273  0.034993
# 13   9789.586909  0.037285
# 14   9777.290545  0.039786
# 15   9764.994182  0.042396
# 16   9752.697818  0.045218
# 17   9740.401455  0.048150
# 18   9728.105091  0.051295
# 19   9715.808727  0.054653

# %% [markdown]
# 这里我发现如果使用水流量作为一个特征，结果还是比较差的，因此我决定直接使用未标准化的污染比作为预测依据
#
# 同时经过反复调试，发现直接使用线性最小二乘挺好的，用Lasso和岭回归会出现问题，这个稍后总结

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression
df_X=df1[['污染比']]

### 0-1标准化 MinMaxScaler
from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()
X_MinMax = min_max_scaler.fit_transform(df_X)
X_MinMax

from sklearn.linear_model import Ridge
df_X=df1[['污染比']]

ln = LinearRegression().fit(df_X[:10], df_y[:10])
ln.intercept_
ln.coef_
# Out:
# array([[-580.83023587],
#        [ 301.09699935],
#        [-648.25600984],
#        [ 170.0905103 ],
#        [ 144.46618304],
#        [ 612.21452142]])

# %%
ln.intercept_
# Out:
# array([20.1593817 , 25.95050564, 53.19306048,  7.39154333,  1.09679814,
#        -7.74394502])

# %%
ln.intercept_
# Out:
# array([20.1593817 , 25.95050564, 53.19306048,  7.39154333,  1.09679814,
#        -7.74394502])

# %%
columns = ['I类百分比', 'Ⅱ类百分比', 'Ⅲ类百分比', 'Ⅳ类百分比', 'Ⅴ类百分比', '劣Ⅴ类百分比']
for y in range(len(columns)):
    for x in range(10, 20):
        prediction = float(ln.coef_[y]*df_X.iloc[x] + ln.intercept_[y])
        if prediction > 0:
            df1.iloc[x, y] = prediction
        else:
            df1.iloc[x, y] = 0

df1
#这只是预测占比，还要再处理一下
# Out:
#        I类百分比      Ⅱ类百分比      Ⅲ类百分比      Ⅳ类百分比     Ⅴ类百分比     劣Ⅴ类百分比  \
# 0       15.3       20.2       49.8        9.7       1.9        3.1
# 1       12.2       24.9       43.6       13.3       2.6        3.4
# 2       11.5       24.1       52.8        8.3       1.7        1.6
# 3        5.2       39.8       35.2        9.5       6.2        4.1
# 4        5.2       39.8       35.2        9.5       6.2        4.1
# 5        5.6       32.8       35.6       16.6       4.4        5.3
# 6        5.9       33.1       34.7         14       5.5        6.8
# 7        4.4         44       28.3         10       3.2         10
# 8        4.7       41.5       31.3        6.4       5.8       10.3
# 9        1.2       26.9       39.9       14.8       5.9       11.3
# 10  2.249445   35.23485  33.204046  12.636295  5.551422  11.133728
# 11   1.04335  35.860079  31.857941  12.989488  5.851406  12.404992
# 12         0  36.486876  30.508459  13.343567  6.152143  13.679446
# 13         0  37.176761   29.02315  13.733286   6.48315  15.082176
# 14         0  37.929973  27.401499  14.158777   6.84454  16.613667
# 15         0  38.715916  25.709379  14.602758  7.221635  18.211709
# 16         0  39.565587  23.880053   15.08274  7.629307  19.939329
# 17         0  40.448316  21.979556  15.581396   8.05284  21.734163
# 18         0  41.395179  19.940978  16.116281  8.507144  23.659401
# 19         0  42.406419  17.763798  16.687533  8.992337  25.715535
#
#              水流量       污染比
# 0    9205.000000  0.018903
# 1    9513.000000  0.018186
# 2    9171.260000  0.020063
# 3   13127.000000  0.014931
# 4    9513.000000  0.021865
# 5    9924.000000  0.022370
# 6    8892.800000  0.026538
# 7   10210.000000  0.024584
# 8    9980.000000  0.026754
# 9    9405.000000  0.030303
# 10   9826.476000  0.030835
# 11   9814.179636  0.032912
# 12   9801.883273  0.034993
# 13   9789.586909  0.037285
# 14   9777.290545  0.039786
# 15   9764.994182  0.042396
# 16   9752.697818  0.045218
# 17   9740.401455  0.048150
# 18   9728.105091  0.051295
# 19   9715.808727  0.054653

# %%
df3=df1.copy()
for x in range(10,20):
    total=np.sum(df1.iloc[x,:6])
    for y in range(6):
        per = df1.iloc[x,y]/total
        df3.iloc[x, y] = round(per*100,1)   #保留一位小数
df3
# Out:
#    I类百分比 Ⅱ类百分比 Ⅲ类百分比 Ⅳ类百分比 Ⅴ类百分比 劣Ⅴ类百分比           水流量       污染比
# 0   15.3  20.2  49.8   9.7   1.9    3.1   9205.000000  0.018903
# 1   12.2  24.9  43.6  13.3   2.6    3.4   9513.000000  0.018186
# 2   11.5  24.1  52.8   8.3   1.7    1.6   9171.260000  0.020063
# 3    5.2  39.8  35.2   9.5   6.2    4.1  13127.000000  0.014931
# 4    5.2  39.8  35.2   9.5   6.2    4.1   9513.000000  0.021865
# 5    5.6  32.8  35.6  16.6   4.4    5.3   9924.000000  0.022370
# 6    5.9  33.1  34.7    14   5.5    6.8   8892.800000  0.026538
# 7    4.4    44  28.3    10   3.2     10  10210.000000  0.024584
# 8    4.7  41.5  31.3   6.4   5.8   10.3   9980.000000  0.026754
# 9    1.2  26.9  39.9  14.8   5.9   11.3   9405.000000  0.030303
# 10   2.2  35.2  33.2  12.6   5.6   11.1   9826.476000  0.030835
# 11   1.0  35.9  31.9  13.0   5.9   12.4   9814.179636  0.032912
# 12   0.0  36.4  30.5  13.3   6.1   13.7   9801.883273  0.034993
# 13   0.0  36.6  28.6  13.5   6.4   14.9   9789.586909  0.037285
# 14   0.0  36.8  26.6  13.8   6.6   16.1   9777.290545  0.039786
# 15   0.0  37.1  24.6  14.0   6.9   17.4   9764.994182  0.042396
# 16   0.0  37.3  22.5  14.2   7.2   18.8   9752.697818  0.045218
# 17   0.0  37.5  20.4  14.5   7.5   20.2   9740.401455  0.048150
# 18   0.0  37.8  18.2  14.7   7.8   21.6   9728.105091  0.051295
# 19   0.0  38.0  15.9  15.0   8.1   23.0   9715.808727  0.054653

# %%
df3.columns[:6]
# Out:
# Index(['I类百分比', 'Ⅱ类百分比', 'Ⅲ类百分比', 'Ⅳ类百分比', 'Ⅴ类百分比', '劣Ⅴ类百分比'], dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 创建一个2x3的网格布局，绘制每个变量的变化趋势
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))

# 遍历每一列，绘制对应变量的线图
for i, column in enumerate(df3.columns[:6].tolist()):
    row = i // 3
    col = i % 3
    ax = axes[row, col]
    
    df3[column].astype(float).plot(ax=ax, legend=False)
    ax.set_title(column)
    ax.set_xlabel('Time')
    ax.set_ylabel('Value')

# 调整子图之间的间距
plt.tight_layout()
plt.show()

# %% [markdown]
# # 第四题
# 这里我决定直接先对第四类和第五类百分比进行求和，然后其和水流量和污染比进行最小二乘的计算

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression
df_X=df1[['污染比']]

### 0-1标准化 MinMaxScaler
from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()
X_MinMax = min_max_scaler.fit_transform(df_X)
X_MinMax

from sklearn.linear_model import Ridge
df_X=df1[['污染比']]

ln = LinearRegression().fit(df_X[:10], df_y[:10])
ln.intercept_
ln.coef_

# %%
df_X=df_X.iloc[:10,:]
df_X_temp=df3['水流量']
df_X_temp=df_X_temp.iloc[:10]
df_X['水流量']=df_X_temp.values
df_y=df3[['Ⅳ类百分比','Ⅴ类百分比']]
df_y=df_y.iloc[:10]
df_y['垃圾水占比']=df_y['Ⅳ类百分比'].astype(float)+df_y['Ⅴ类百分比'].astype(float)
df_y=df_y['垃圾水占比']
df_y
# Out:
# 0    11.6
# 1    15.9
# 2    10.0
# 3    15.7
# 4    15.7
# 5    21.0
# 6    19.5
# 7    13.2
# 8    12.2
# 9    20.7
# Name: 垃圾水占比, dtype: float64

# %% [markdown]
# # 第五题
# 你对解决长江水质污染问题有什么切实可行的建议和意见
#
# 略

# %% [markdown]
# # 后记
# pd.concat的使用
